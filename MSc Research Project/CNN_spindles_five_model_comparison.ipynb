# %%
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import mne
import matplotlib.pyplot as plt
import pyvista
import ipywidgets
import ipyevents
import pyvistaqt
import yasa
import os
import random

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score, roc_curve, auc, precision_score, recall_score
from sklearn.utils import class_weight
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

import scipy.signal as signal
from scipy.signal import hilbert
from scipy.signal import stft

from scipy.stats import friedmanchisquare
from scipy.stats import ttest_rel, wilcoxon, shapiro

import pywt
import cv2

SEED = 15

os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# %%
# %matplotlib qt

# %% [markdown]
# ## CNN Models

# %%
def build_cnn_model_downsampled(input_shape=(300,1)):

    # linear embedding layer
    input_layer = tf.keras.layers.Input(shape=input_shape)

    # Three convolutional blocks (like having three pattern detectors)

    # First convolution block, kernel size of 5
    padded1 = tf.keras.layers.ZeroPadding1D(padding=2)(input_layer)
    conv1 = tf.keras.layers.Conv1D(filters=10, kernel_size=5, strides=1, padding='valid')(padded1)
    # each filter learns a different type of short-time feature
    # stride of 1, moves one step at a time
    conv1 = tf.keras.layers.LeakyReLU(alpha=0.01)(conv1)
    conv1 = tf.keras.layers.MaxPooling1D(pool_size=2)(conv1)
    # K = 2
    conv1 = tf.keras.layers.BatchNormalization()(conv1)

    # Second convolution block, kernel size of 11
    padded2 = tf.keras.layers.ZeroPadding1D(padding=5)(input_layer)
    conv2 = tf.keras.layers.Conv1D(filters=10, kernel_size=11, strides=1, padding='valid')(padded2)
    conv2 = tf.keras.layers.LeakyReLU(alpha=0.01)(conv2)
    conv2 = tf.keras.layers.MaxPooling1D(pool_size=2)(conv2)
    conv2 = tf.keras.layers.BatchNormalization()(conv2)

    # Third convolution block, kernel size of 21
    padded3 = tf.keras.layers.ZeroPadding1D(padding=10)(input_layer)
    conv3 = tf.keras.layers.Conv1D(filters=10, kernel_size=21, strides=1, padding='valid')(padded3)
    conv3 = tf.keras.layers.LeakyReLU(alpha=0.01)(conv3)
    conv3 = tf.keras.layers.MaxPooling1D(pool_size=2)(conv3)
    conv3 = tf.keras.layers.BatchNormalization()(conv3)

    # Concatenate the outputs of all blocks
    concatenated = tf.keras.layers.Concatenate()([conv1, conv2, conv3])

    # GRU Layer
    gru = tf.keras.layers.GRU(64)(concatenated)

    # Fully connected (dense) layer
    dense = tf.keras.layers.Dense(64, activation='relu')(gru)
    # add a Dropout layer to prevent overfitting
    #dense = tf.keras.layers.Dropout(0.5)(dense)

    # Two softmax outputs for dual-task classification
    #output_task1 = tf.keras.layers.Dense(2, activation='softmax', name='task1')(dense)
    #output_task2 = tf.keras.layers.Dense(2, activation='softmax', name='task2')(dense)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(dense)

    # Create the model
    #model = tf.keras.models.Model(inputs=input_layer, outputs=[output_task1, output_task2])
    model = tf.keras.models.Model(inputs=input_layer, outputs=output)

    # Compile the model
    #model.compile(optimizer='adam', loss={'task1': 'categorical_crossentropy', 'task2': 'categorical_crossentropy'}, metrics={'task1': 'accuracy', 'task2': 'accuracy'})
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    # Return the compiled model
    return model

# %%
def build_multi_input_cnn_model_filtered():
    # Inputs
    input_raw = tf.keras.Input(shape=(300, 1), name='raw_input')
    input_filtered = tf.keras.Input(shape=(300, 1), name='filtered_input') 

    def conv_branch(input_layer, kernel_sizes=[5, 11, 21]):
        outputs = []
        for k in kernel_sizes:
            pad = k // 2
            x = tf.keras.layers.ZeroPadding1D(padding=pad)(input_layer)
            x = tf.keras.layers.Conv1D(filters=10, kernel_size=k, strides=1, padding='valid')(x)
            x = tf.keras.layers.LeakyReLU(negative_slope=0.01)(x)
            x = tf.keras.layers.MaxPooling1D(pool_size=2)(x)
            x = tf.keras.layers.BatchNormalization()(x)
            outputs.append(x)
        return tf.keras.layers.Concatenate()(outputs)

    # Convolutional branches
    branch_raw = conv_branch(input_raw)
    branch_filtered = conv_branch(input_filtered)

    # Each branch through its own GRU
    gru_raw = tf.keras.layers.GRU(64)(branch_raw)
    gru_filtered = tf.keras.layers.GRU(64)(branch_filtered)

    # Concatenate GRU outputs (fixed-length vectors)
    merged = tf.keras.layers.Concatenate()([gru_raw, gru_filtered])

    # Dense layers
    x = tf.keras.layers.Dense(64, activation='relu')(merged)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    # Build model
    model = tf.keras.Model(inputs=[input_raw, input_filtered], outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
def build_multi_input_cnn_model_freq():
    # Inputs
    input_raw = tf.keras.Input(shape=(300, 1), name='raw_input')
    input_filtered = tf.keras.Input(shape=(300, 1), name='filtered_input')
    input_stft = tf.keras.Input(shape=(13, 1), name='stft_input')  

    def conv_branch(input_layer, kernel_sizes=[5, 11, 21]):
        outputs = []
        for k in kernel_sizes:
            pad = k // 2
            x = tf.keras.layers.ZeroPadding1D(padding=pad)(input_layer)
            x = tf.keras.layers.Conv1D(filters=10, kernel_size=k, strides=1, padding='valid')(x)
            x = tf.keras.layers.LeakyReLU(negative_slope=0.01)(x)
            x = tf.keras.layers.MaxPooling1D(pool_size=2)(x)
            x = tf.keras.layers.BatchNormalization()(x)
            outputs.append(x)
        return tf.keras.layers.Concatenate()(outputs)

    # Convolutional branches
    branch_raw = conv_branch(input_raw)
    branch_filtered = conv_branch(input_filtered)
    branch_stft = conv_branch(input_stft)

    # Each branch through its own GRU
    gru_raw = tf.keras.layers.GRU(64)(branch_raw)
    gru_filtered = tf.keras.layers.GRU(64)(branch_filtered)
    gru_stft = tf.keras.layers.GRU(64)(branch_stft)

    # Concatenate GRU outputs (fixed-length vectors)
    merged = tf.keras.layers.Concatenate()([gru_raw, gru_filtered, gru_stft])

    # Dense layers
    x = tf.keras.layers.Dense(64, activation='relu')(merged)
    output = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    # Build model
    model = tf.keras.Model(inputs=[input_raw, input_filtered, input_stft], outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# ## Spindle detection function

# %%
def detect_spindles_times(eeg_raw, do_filter=True, do_downsample=False, downsample_rate=100):
    
    # 1. Filter between 12 and 16 Hz
    
    data = eeg_raw.copy().pick_channels(['Fz'])

    if do_filter:
        data.filter(l_freq=12, h_freq=16)
    
    # 2. Downsample at 100 Hz (100 samples per second)

    if do_downsample:
        data.resample(downsample_rate)
    
    sfreq = data.info['sfreq']  
    channel_data = data.get_data()[0]
    # extract the filtered data
    
    
    # 3: Calculate amplitude by applying Hilbert transformation

    hilbert_signal = hilbert(channel_data)
    # apply hilbert transformation to bandpassed data
    # gives analytic signal with amplitude and phase information
    envelope = np.abs(hilbert_signal)
    # take the absolute part of the hilbert signal
    # also the instantaneous power of the signal
    # gives the envelope: amplitude modulation
    # how strength of oscillations change over time
    # size of sliding window
    
    # 4: Perform smoothing with a sliding window of 0.2 seconds
    # this removes high-frequency noise
    
    sliding_window = int(0.2 * sfreq)
    smoothed_envelope = np.convolve(envelope, np.ones(sliding_window) / sliding_window, mode='same')
    # convolving envelope with a uniform filter over the sliding window
    # convolution takes rolling average of 20 samples at a time
    # smooth the signal with the average of values in the window
    # in the smoothed envelope, can detect regions with higher amplitude 
    # which is when a spindle event occurs
    # np.ones: creates a filter kernel
    # have a filter where the sum of all elements equals 1
    # this filter is replaced by the average of the 20 surrounding samples
    # convolution between envelope and averaging filter
    # mode = 'same': so that output of convolution has same length as original envelope

    # 5. Define spindle detection threshold

    threshold = np.percentile(smoothed_envelope, 75)
    spindle_threshold = smoothed_envelope > threshold
    #threshold = np.mean(smoothed_envelope) + 1.5 * np.std(smoothed_envelope)
    #spindle_threshold = smoothed_envelope > threshold
    # threshold is 75th percentile of the smoothed envelope
    # will look at the duration later
    
    # 6. Detect spindles and define peaks and troughs for visualisation
    
    spindles = []
    # initialize list with spindles
    above_threshold = np.where(spindle_threshold)[0]
    # returns indices where signal above the threshold
    stacked_spindles = []
    # initialize list for stacking the spindles for the visualisation
    # contains aligned spindles at peak
    
    if len(above_threshold) > 0:
        # checking it's not empty
        start_idx = above_threshold[0]
        # would be the start of a potential spindle
        for i in range(1, len(above_threshold)):
            if above_threshold[i] > above_threshold[i - 1] + 1:  
                # if above threshold[1] > above_threshold[0] + 1
                # because all indices should be separated by 1
                # so here detects gaps
                # so starting from the second index
                # and comparing each index to the one before
                end_idx = above_threshold[i - 1]
                # so if above condition is true, this is the end of the spindle
                duration = (end_idx - start_idx) / sfreq
                if 0.5 <= duration <= 3:
                    # only keep spindles lasting 0.5 to 3 seconds
                    segment = channel_data[start_idx:end_idx]
                    # extract EEG segment corresponding to detected spindle
                    peak_idx = start_idx + np.argmax(segment) 
                    # extract the peak of the spindle
                    # this will be useful for later
                    spindles.append((start_idx / sfreq, end_idx / sfreq))
                    # all the spindles are stored in spindles
                    
                    # Aligning spindles at peak for visualization
                    before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
                    # still in the for loop, so this is the peak index of individual peak
                    after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
                    # extracting 1.5 seconds before and after peak
                    # max and min are used for out of bounds situations at the start and end of EEG data
                    aligned_segment = channel_data[before_peak_idx:after_peak_idx]
                    stacked_spindles.append(aligned_segment)
                    # the aligned segment is saved in stacked spindles
                
                start_idx = above_threshold[i]
                # update the start index for the for loop

        # then need to process the final spindle
        end_idx = above_threshold[-1]
        duration = (end_idx - start_idx) / sfreq
        if 0.5 <= duration <= 3:
            segment = channel_data[start_idx:end_idx]
            peak_idx = start_idx + np.argmax(segment)
            spindles.append((start_idx / sfreq, end_idx / sfreq))

            before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
            after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
            aligned_segment = channel_data[before_peak_idx:after_peak_idx]
            stacked_spindles.append(aligned_segment)
    
    return spindles
    

def detect_spindles_peaks(eeg_raw, do_filter=True, do_downsample=False, downsample_rate=100):
    
    # 1. Filter between 12 and 16 Hz
    
    data = eeg_raw.copy().pick_channels(['Fz'])

    if do_filter:
        data.filter(l_freq=12, h_freq=16)
    
    # 2. Downsample at 100 Hz (100 samples per second)
    
    if do_downsample:
        data.resample(downsample_rate)
        
    sfreq = data.info['sfreq']  
    # update to new sampling frequency
    # because used later in the code
    channel_data = data.get_data()[0]
    # extract the filtered data
    
    # 3: Calculate amplitude by applying Hilbert transformation

    hilbert_signal = hilbert(channel_data)
    # apply hilbert transformation to bandpassed data
    # gives analytic signal with amplitude and phase information
    envelope = np.abs(hilbert_signal)
    # take the absolute part of the hilbert signal
    # also the instantaneous power of the signal
    # gives the envelope: amplitude modulation
    # how strength of oscillations change over time
    # size of sliding window
    
    # 4: Perform smoothing with a sliding window of 0.2 seconds
    # this removes high-frequency noise
    
    sliding_window = int(0.2 * sfreq)
    smoothed_envelope = np.convolve(envelope, np.ones(sliding_window) / sliding_window, mode='same')
    # convolving envelope with a uniform filter over the sliding window
    # convolution takes rolling average of 20 samples at a time
    # smooth the signal with the average of values in the window
    # in the smoothed envelope, can detect regions with higher amplitude 
    # which is when a spindle event occurs
    # np.ones: creates a filter kernel
    # have a filter where the sum of all elements equals 1
    # this filter is replaced by the average of the 20 surrounding samples
    # convolution between envelope and averaging filter
    # mode = 'same': so that output of convolution has same length as original envelope

    # 5. Define spindle detection threshold

    threshold = np.percentile(smoothed_envelope, 75)
    spindle_threshold = smoothed_envelope > threshold
    # 75th percentile as criteria

    #threshold = np.mean(smoothed_envelope) + 1.5 * np.std(smoothed_envelope)
    #spindle_threshold = smoothed_envelope > threshold
    
    # 6. Detect spindles and define peaks and troughs for visualisation
    
    spindles = []
    # initialize list with spindles
    above_threshold = np.where(spindle_threshold)[0]
    # returns indices where signal above the threshold
    stacked_spindles = []
    # initialize list for stacking the spindles for the visualisation
    # contains aligned spindles at peak
    
    if len(above_threshold) > 0:
        # checking it's not empty
        start_idx = above_threshold[0]
        # would be the start of a potential spindle
        for i in range(1, len(above_threshold)):
            if above_threshold[i] > above_threshold[i - 1] + 1:  
                # if above threshold[1] > above_threshold[0] + 1
                # because all indices should be separated by 1
                # so here detects gaps
                end_idx = above_threshold[i - 1]
                # so if above condition is true, this is the end of the spindle
                duration = (end_idx - start_idx) / sfreq
                if 0.5 <= duration <= 3:
                    # only keep spindles lasting 0.5 to 3 seconds
                    segment = channel_data[start_idx:end_idx]
                    # extract EEG segment corresponding to detected spindle
                    peak_idx = start_idx + np.argmax(segment) 
                    # extract the peak of the spindle
                    # this will be useful for later
                    #spindles.append(f"Spindle detected from {start_idx / sfreq:.2f}s to {end_idx / sfreq:.2f}s, peak at {peak_idx / sfreq:.2f}s")
                    spindles.append((peak_idx / sfreq))
                    # all the spindles are stored in spindles
                    
                    # Aligning spindles at peak for visualization
                    before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
                    # still in the for loop, so this is the peak index of individual peak
                    after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
                    # extracting 1.5 seconds before and after peak
                    # max and min are used for out of bounds situations at the start and end of EEG data
                    aligned_segment = channel_data[before_peak_idx:after_peak_idx]
                    stacked_spindles.append(aligned_segment)
                    # the aligned segment is saved in stacked spindles
                
                start_idx = above_threshold[i]
                # update the start index for the for loop

        # then need to process the final spindle
        end_idx = above_threshold[-1]
        duration = (end_idx - start_idx) / sfreq
        if 0.5 <= duration <= 3:
            segment = channel_data[start_idx:end_idx]
            peak_idx = start_idx + np.argmax(segment)
            spindles.append((peak_idx / sfreq))

            before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
            after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
            aligned_segment = channel_data[before_peak_idx:after_peak_idx]
            stacked_spindles.append(aligned_segment)

    
    return spindles

# %% [markdown]
# ## Epochs function

# %%
def create_fixed_length_epochs(raw, duration=3.0, overlap=0.0, preload=True, reject_by_annotation=False):

    return mne.make_fixed_length_epochs(
        raw,
        duration=duration,
        overlap=overlap,
        preload=preload,
        reject_by_annotation=reject_by_annotation
    )
# function mne.make_fixed_length_epochs takes into account the sampling frequency of the data


def label_spindle_epochs_moderate(epochs, spindle_starts, spindle_ends, epoch_length_sec=3.0):
    epoch_starts = np.arange(len(epochs)) * epoch_length_sec
    epoch_labels = np.zeros(len(epochs), dtype=int)

    for spindle_start, spindle_end in zip(spindle_starts, spindle_ends):
        spindle_duration = spindle_end - spindle_start
        required_overlap = 0.5 * spindle_duration  
        # only label 1 if epoch contains 50% of the spindle duration

        for i, epoch_start in enumerate(epoch_starts):
            epoch_end = epoch_start + epoch_length_sec

            # Calculate overlap between spindle and epoch
            overlap_start = max(spindle_start, epoch_start)
            overlap_end = min(spindle_end, epoch_end)
            overlap_duration = overlap_end - overlap_start

            if overlap_duration >= required_overlap:
                epoch_labels[i] = 1

    return epoch_labels

# %% [markdown]
# ## Importing data

# %%
# for 5-fold validation
# load the all the files needed that were pre-processed before
# from train_1_raw and test_1_raw to train_5_raw and test_5_raw
split_files = {
    f'split_{i}': {
        'train': fr"C:\EEG DATA\combined_sets\train_{i}_raw.fif",
        'test': fr"C:\EEG DATA\combined_sets\test_{i}_raw.fif"
    } for i in range(1, 6) 
}

raw_splits = {}
for split_name, files in split_files.items():
    print(f"Loading data for {split_name}...")
    try:
        train_raw = mne.io.read_raw_fif(files['train'], preload=True)
        test_raw = mne.io.read_raw_fif(files['test'], preload=True)
        raw_splits[split_name] = {'train': train_raw, 'test': test_raw}
        print(f"Loaded train and test data for {split_name}")
    except FileNotFoundError as e:
        print(f"Error: File not found for {split_name}: {e}")
        # error in case the file does not exist
    except Exception as e:
        print(f"Error loading data for {split_name}: {e}")
        # errors in case not loading data

        # error statements useful if running this notebook on another laptop
# Out:
# Loading data for split_1...
# Opening raw data file C:\EEG DATA\combined_sets\train_1_raw.fif...
# Isotrak not found
#     Range : 90000 ... 32700095 =    180.000 ... 65400.190 secs
# Ready.
# Reading 0 ... 32610095  =      0.000 ... 65220.190 secs...
# Opening raw data file C:\EEG DATA\combined_sets\test_1_raw.fif...
# Isotrak not found
#     Range : 1470000 ... 7845026 =   2940.000 ... 15690.052 secs
# Ready.
# Reading 0 ... 6375026  =      0.000 ... 12750.052 secs...
# Loaded train and test data for split_1
# Loading data for split_2...
# Opening raw data file C:\EEG DATA\combined_sets\train_2_raw.fif...
# Isotrak not found
#     Range : 1470000 ... 32985091 =   2940.000 ... 65970.182 secs
# Ready.
# Reading 0 ... 31515091  =      0.000 ... 63030.182 secs...
# Opening raw data file C:\EEG DATA\combined_sets\test_2_raw.fif...
# Isotrak not found
#     Range : 90000 ... 7560030 =    180.000 ... 15120.060 secs
# Ready.
# Reading 0 ... 7470030  =      0.000 ... 14940.060 secs...
# Loaded train and test data for split_2
# Loading data for split_3...
# Opening raw data file C:\EEG DATA\combined_sets\train_3_raw.fif...
# Isotrak not found
#     Range : 1470000 ... 32475107 =   2940.000 ... 64950.214 secs
# Ready.
# Reading 0 ... 31005107  =      0.000 ... 62010.214 secs...
# Opening raw data file C:\EEG DATA\combined_sets\test_3_raw.fif...
# Isotrak not found
#     Range : 300000 ... 8280014 =    600.000 ... 16560.028 secs
# Ready.
# Reading 0 ... 7980014  =      0.000 ... 15960.028 secs...
# Loaded train and test data for split_3
# Loading data for split_4...
# Opening raw data file C:\EEG DATA\combined_sets\train_4_raw.fif...
# Isotrak not found
#     Range : 1470000 ... 32100090 =   2940.000 ... 64200.180 secs
# Ready.
# Reading 0 ... 30630090  =      0.000 ... 61260.180 secs...
# Opening raw data file C:\EEG DATA\combined_sets\test_4_raw.fif...
# Isotrak not found
#     Range : 825000 ... 9180031 =   1650.000 ... 18360.062 secs
# Ready.
# Reading 0 ... 8355031  =      0.000 ... 16710.062 secs...
# Loaded train and test data for split_4
# Loading data for split_5...
# Opening raw data file C:\EEG DATA\combined_sets\train_5_raw.fif...
# Isotrak not found
#     Range : 1470000 ... 31650104 =   2940.000 ... 63300.208 secs
# Ready.
# Reading 0 ... 30180104  =      0.000 ... 60360.208 secs...
# Opening raw data file C:\EEG DATA\combined_sets\test_5_raw.fif...
# Isotrak not found
#     Range : 165000 ... 8970017 =    330.000 ... 17940.034 secs
# Ready.
# Reading 0 ... 8805017  =      0.000 ... 17610.034 secs...
# Loaded train and test data for split_5

# %% [markdown]
# ## Training

# %%
# we want to evaluate the models on all these scores
model_metrics = {
    'one_input_cnn': {
        'f1_scores': [],
        'precision_scores': [],
        'recall_scores': []
    },
    'two_input_cnn': {
        'f1_scores': [],
        'precision_scores': [],
        'recall_scores': []
    },
    'three_input_cnn': {
        'f1_scores': [],
        'precision_scores': [],
        'recall_scores': []
    }
}


# will evaluate the three models
# model 1: raw
# model 2: raw + filtered
# model 3: raw + filtered + STFT frequency
models_to_evaluate = {
    'one_input_cnn': build_cnn_model_downsampled,
    'two_input_cnn': build_multi_input_cnn_model_filtered,
    'three_input_cnn': build_multi_input_cnn_model_freq
}

# then we go through each split
# so create a for loop
for split_name, raw_data in raw_splits.items():
    print(f"\n--- Processing Split: {split_name} ---")
    # when running the code for a long time, allows you to know at which stage it's at
    train_raw = raw_data['train']
    test_raw = raw_data['test']

    # this is for each split

    # spindle detection on raw data
    # this is for model 1 and model 3
    spindles_train_times_raw = detect_spindles_times(train_raw, do_filter=True, do_downsample=True)
    spindles_test_times_raw = detect_spindles_times(test_raw, do_filter=True, do_downsample=True)
    spindles_starts_train_raw, spindles_ends_train_raw = zip(*spindles_train_times_raw) if spindles_train_times_raw else ([], [])
    spindles_starts_test_raw, spindles_ends_test_raw = zip(*spindles_test_times_raw) if spindles_test_times_raw else ([], [])
    # Downsample raw data for one input
    train_raw_downsampled = train_raw.copy().resample(100)
    test_raw_downsampled = test_raw.copy().resample(100)

    # for model 2, first filter and downsample
    train_filtered = train_raw.copy().filter(l_freq=12, h_freq=16)
    test_filtered = test_raw.copy().filter(l_freq=12, h_freq=16)
    train_filtered = train_filtered.resample(100)
    test_filtered = test_filtered.resample(100)

    # spindle detection for model 2
    spindles_train_times_filtered = detect_spindles_times(train_filtered, do_filter=False, do_downsample=False) 
    # false because already filtered and downsampled
    spindles_test_times_filtered = detect_spindles_times(test_filtered, do_filter=False, do_downsample=False) 
    spindles_starts_train_filtered, spindles_ends_train_filtered = zip(*spindles_train_times_filtered) if spindles_train_times_filtered else ([], [])
    spindles_starts_test_filtered, spindles_ends_test_filtered = zip(*spindles_test_times_filtered) if spindles_test_times_filtered else ([], [])


    # create fixed length epochs, are of 3 seconds each
    epochs_train_raw_downsampled = create_fixed_length_epochs(train_raw_downsampled)
    epochs_test_raw_downsampled = create_fixed_length_epochs(test_raw_downsampled)

    epochs_train_filtered_downsampled = create_fixed_length_epochs(train_filtered)
    epochs_test_filtered_downsampled = create_fixed_length_epochs(test_filtered)


    # STFT input for model 3
    # created on epochs from raw downsampled data
    epochs_train_stft_downsampled = np.squeeze(np.array(epochs_train_raw_downsampled))
    epochs_test_stft_downsampled = np.squeeze(np.array(epochs_test_raw_downsampled))

    fs = train_raw_downsampled.info['sfreq']
    nperseg = 50
    noverlap = nperseg // 2

    X_train_stft_transformed = []
    for epoch in epochs_train_stft_downsampled:
        f, t, Zxx = stft(epoch, fs=fs, nperseg=nperseg, noverlap=noverlap)
        spectrogram = np.abs(Zxx)
        X_train_stft_transformed.append(spectrogram)
    X_train_stft_transformed = np.array(X_train_stft_transformed)

    X_test_stft_transformed = []
    for epoch in epochs_test_stft_downsampled:
        f, t, Zxx = stft(epoch, fs=fs, nperseg=nperseg, noverlap=noverlap)
        spectrogram = np.abs(Zxx)
        X_test_stft_transformed.append(spectrogram)
    X_test_stft_transformed = np.array(X_test_stft_transformed)

    # only keep the frequency dimension of STFT
    X_train_stft_freq = np.mean(X_train_stft_transformed, axis=1)
    X_test_stft_freq = np.mean(X_test_stft_transformed, axis=1)
    X_train_stft_freq = X_train_stft_freq[..., np.newaxis] 
    # to have correct input size for CNN, adds channel dimension
    X_test_stft_freq = X_test_stft_freq[..., np.newaxis] 

    # normalize per epoch
    X_train_stft_freq_norm = np.array([
        (epoch - np.min(epoch)) / (np.max(epoch) - np.min(epoch) + 1e-8)
        for epoch in X_train_stft_freq
    ])
    X_test_stft_freq_norm = np.array([
        (epoch - np.min(epoch)) / (np.max(epoch) - np.min(epoch) + 1e-8)
        for epoch in X_test_stft_freq
    ])


    # reshape the epochs for model 1 and model 2
    X_train_raw = np.array(epochs_train_raw_downsampled).reshape(len(epochs_train_raw_downsampled), -1, 1)
    X_test_raw = np.array(epochs_test_raw_downsampled).reshape(len(epochs_test_raw_downsampled), -1, 1)

    X_train_filtered = np.array(epochs_train_filtered_downsampled).reshape(len(epochs_train_filtered_downsampled), -1, 1)
    X_test_filtered = np.array(epochs_test_filtered_downsampled).reshape(len(epochs_test_filtered_downsampled), -1, 1)


    # still in the same split
    # now iterate through the models
    for model_name, build_model_func in models_to_evaluate.items():
        print(f"\n--- Evaluating Model: {model_name} on {split_name} ---")

        # here define X and y sets
        # y set defined by assigning labels
        if model_name == 'one_input_cnn':
            X_train_input = X_train_raw
            X_test_input = X_test_raw
            y_train = label_spindle_epochs_moderate(epochs_train_raw_downsampled, spindles_starts_train_raw, spindles_ends_train_raw)
            y_test = label_spindle_epochs_moderate(epochs_test_raw_downsampled, spindles_starts_test_raw, spindles_ends_test_raw)
            input_shape = (X_train_input.shape[1], X_train_input.shape[2])

        elif model_name == 'two_input_cnn':
             X_train_input = {
                 'raw_input': X_train_raw,
                 'filtered_input': X_train_filtered
             }
             X_test_input = {
                 'raw_input': X_test_raw,
                 'filtered_input': X_test_filtered
             }
             y_train = label_spindle_epochs_moderate(epochs_train_raw_downsampled, spindles_starts_train_raw, spindles_ends_train_raw)
             y_test = label_spindle_epochs_moderate(epochs_test_raw_downsampled, spindles_starts_test_raw, spindles_ends_test_raw)
             input_shape = None
            # when input shape = None, infers it itself

        elif model_name == 'three_input_cnn':
            X_train_input = {
                'raw_input': X_train_raw,
                'filtered_input': X_train_filtered,
                'stft_input': X_train_stft_freq_norm 
            }
            X_test_input = {
                'raw_input': X_test_raw,
                'filtered_input': X_test_filtered,
                'stft_input': X_test_stft_freq_norm 
            }
            # Labels for the three-input model come from the raw downsampled data
            y_train = label_spindle_epochs_moderate(epochs_train_raw_downsampled, spindles_starts_train_raw, spindles_ends_train_raw)
            y_test = label_spindle_epochs_moderate(epochs_test_raw_downsampled, spindles_starts_test_raw, spindles_ends_test_raw)

            input_shape = None 

        print(f"Training data shapes: { {k: v.shape for k, v in X_train_input.items()} if isinstance(X_train_input, dict) else X_train_input.shape}, labels={y_train.shape}")
        print(f"Test data shapes: { {k: v.shape for k, v in X_test_input.items()} if isinstance(X_test_input, dict) else X_test_input.shape}, labels={y_test.shape}")
        # to check whether a dictionary or not 
        # because it is a dictionary for the three-input model
        # but not for the other models


        # build the models

        print("Building and compiling model...")
        if model_name in ['one_input_cnn']:
             model = build_model_func(input_shape)
        else:
            model = build_model_func()


        # define early stopping
        # if validation loss does not change after 5 epochs
        # stop training
        early_stop = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )

        # Train the model
        print("Training the model...")
        # keep 20% of training set as validation
        # this is useful to detect overfitting
        history = model.fit(
            X_train_input,
            y_train,
            validation_split=0.2,
            epochs=20, # Adjust epochs as needed
            batch_size=128, # Adjust batch size as needed
            callbacks=[early_stop], # Optional: Use early stopping
        )
        print("Training finished.")

        # this evaluates the model on test data of split (unseen data)
        # these are the predictions
        print(f"Evaluating on {split_name}'s test data...")
        loss, accuracy = model.evaluate(X_test_input, y_test, verbose=0)
        print(f"Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")
        # useful to compare to accuracy and loss of training and validation set
        # to detect any overfitting

        # now that have the predictions can calculate the F1 score
        # and also accuracy and recall
        y_pred_proba = model.predict(X_test_input, verbose=0)
        y_pred_labels = (y_pred_proba > 0.5).astype(int)

        split_f1 = f1_score(y_test, y_pred_labels)
        split_precision = precision_score(y_test, y_pred_labels)
        split_recall = recall_score(y_test, y_pred_labels)
        print(f"F1 Score for {model_name} on {split_name}: {split_f1:.4f}")
        print(f"Precision for {model_name} on {split_name}: {split_precision:.4f}")
        print(f"Recall for {model_name} on {split_name}: {split_recall:.4f}")

        # store all the metrics
        # then move on to next step
        model_metrics[model_name]['f1_scores'].append(split_f1)
        model_metrics[model_name]['precision_scores'].append(split_precision)
        model_metrics[model_name]['recall_scores'].append(split_recall)

        # clears tensorflow 
        # this is to free up memory
        tf.keras.backend.clear_session()

print("\n--- Evaluation finished for all models across all splits ---")
# Out:
# --- Processing Split: split_1 ---
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 96 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 96 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Not setting metadata
# 21740 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 21740 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 4250 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 4250 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 21740 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 21740 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 4250 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 4250 events and 300 original time points ...
# 0 bad epochs dropped
#
# --- Evaluating Model: one_input_cnn on split_1 ---
# Training data shapes: (21740, 300, 1), labels=(21740,)
# Test data shapes: (4250, 300, 1), labels=(4250,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# C:\Users\roseb\anaconda3\envs\msc_research_project\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.5630 - loss: 0.6829 - val_accuracy: 0.5584 - val_loss: 0.6818
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 15s 110ms/step - accuracy: 0.6277 - loss: 0.6515 - val_accuracy: 0.6789 - val_loss: 0.6132
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 15s 110ms/step - accuracy: 0.6702 - loss: 0.6035 - val_accuracy: 0.6391 - val_loss: 0.6110
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 15s 110ms/step - accuracy: 0.6152 - loss: 0.6469 - val_accuracy: 0.5345 - val_loss: 0.6915
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - accuracy: 0.5911 - loss: 0.6700 - val_accuracy: 0.5964 - val_loss: 0.6575
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - accuracy: 0.6353 - loss: 0.6422 - val_accuracy: 0.6095 - val_loss: 0.6597
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.6527 - loss: 0.6225 - val_accuracy: 0.6693 - val_loss: 0.6105
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.7023 - loss: 0.5745 - val_accuracy: 0.6014 - val_loss: 0.6472
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.6609 - loss: 0.6227 - val_accuracy: 0.6355 - val_loss: 0.6518
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - accuracy: 0.7397 - loss: 0.5329 - val_accuracy: 0.7397 - val_loss: 0.5217
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.7800 - loss: 0.4829 - val_accuracy: 0.6884 - val_loss: 0.5870
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.7280 - loss: 0.5342 - val_accuracy: 0.7236 - val_loss: 0.5285
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - accuracy: 0.7749 - loss: 0.4770 - val_accuracy: 0.7705 - val_loss: 0.4696
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - accuracy: 0.7674 - loss: 0.4911 - val_accuracy: 0.6755 - val_loss: 0.5919
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - accuracy: 0.7794 - loss: 0.4674 - val_accuracy: 0.7532 - val_loss: 0.5543
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.8151 - loss: 0.3966 - val_accuracy: 0.8172 - val_loss: 0.3977
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - accuracy: 0.8278 - loss: 0.3721 - val_accuracy: 0.8344 - val_loss: 0.3603
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - accuracy: 0.8370 - loss: 0.3565 - val_accuracy: 0.8441 - val_loss: 0.3489
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.8425 - loss: 0.3464 - val_accuracy: 0.8496 - val_loss: 0.3335
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.8422 - loss: 0.3482 - val_accuracy: 0.8360 - val_loss: 0.3546
# Training finished.
# Evaluating on split_1's test data...
# Loss: 0.3464, Accuracy: 0.8409
# F1 Score for one_input_cnn on split_1: 0.8220
# Precision for one_input_cnn on split_1: 0.8433
# Recall for one_input_cnn on split_1: 0.8017
# 24-Jul-25 15:31:35 | WARNING | From C:\Users\roseb\anaconda3\envs\msc_research_project\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# --- Evaluating Model: two_input_cnn on split_1 ---
# Training data shapes: {'raw_input': (21740, 300, 1), 'filtered_input': (21740, 300, 1)}, labels=(21740,)
# Test data shapes: {'raw_input': (4250, 300, 1), 'filtered_input': (4250, 300, 1)}, labels=(4250,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 38s 237ms/step - accuracy: 0.6207 - loss: 0.6527 - val_accuracy: 0.4632 - val_loss: 0.7164
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 185ms/step - accuracy: 0.6154 - loss: 0.6052 - val_accuracy: 0.7447 - val_loss: 0.4998
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 187ms/step - accuracy: 0.7984 - loss: 0.4361 - val_accuracy: 0.8735 - val_loss: 0.2876
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 31s 226ms/step - accuracy: 0.8717 - loss: 0.2918 - val_accuracy: 0.8873 - val_loss: 0.2606
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 31s 230ms/step - accuracy: 0.8879 - loss: 0.2594 - val_accuracy: 0.8786 - val_loss: 0.3194
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 33s 240ms/step - accuracy: 0.8620 - loss: 0.3222 - val_accuracy: 0.8917 - val_loss: 0.2491
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 34s 247ms/step - accuracy: 0.8845 - loss: 0.2664 - val_accuracy: 0.9062 - val_loss: 0.2210
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 32s 238ms/step - accuracy: 0.9026 - loss: 0.2297 - val_accuracy: 0.9144 - val_loss: 0.2092
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 34s 253ms/step - accuracy: 0.8840 - loss: 0.2681 - val_accuracy: 0.9066 - val_loss: 0.2261
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 273ms/step - accuracy: 0.9013 - loss: 0.2379 - val_accuracy: 0.9121 - val_loss: 0.2101
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 33s 246ms/step - accuracy: 0.9099 - loss: 0.2188 - val_accuracy: 0.9195 - val_loss: 0.1966
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 33s 243ms/step - accuracy: 0.9170 - loss: 0.2052 - val_accuracy: 0.9243 - val_loss: 0.1881
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 35s 257ms/step - accuracy: 0.9213 - loss: 0.1966 - val_accuracy: 0.9243 - val_loss: 0.1825
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 35s 256ms/step - accuracy: 0.9240 - loss: 0.1901 - val_accuracy: 0.9278 - val_loss: 0.1776
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 35s 257ms/step - accuracy: 0.9280 - loss: 0.1842 - val_accuracy: 0.9315 - val_loss: 0.1737
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 34s 254ms/step - accuracy: 0.9305 - loss: 0.1793 - val_accuracy: 0.9324 - val_loss: 0.1709
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 33s 240ms/step - accuracy: 0.9334 - loss: 0.1750 - val_accuracy: 0.9349 - val_loss: 0.1682
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 34s 250ms/step - accuracy: 0.9357 - loss: 0.1709 - val_accuracy: 0.9379 - val_loss: 0.1660
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 34s 253ms/step - accuracy: 0.9369 - loss: 0.1671 - val_accuracy: 0.9388 - val_loss: 0.1639
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 33s 246ms/step - accuracy: 0.9371 - loss: 0.1647 - val_accuracy: 0.9384 - val_loss: 0.1630
# Training finished.
# Evaluating on split_1's test data...
# Loss: 0.1381, Accuracy: 0.9473
# F1 Score for two_input_cnn on split_1: 0.9433
# Precision for two_input_cnn on split_1: 0.9305
# Recall for two_input_cnn on split_1: 0.9563
#
# --- Evaluating Model: three_input_cnn on split_1 ---
# Training data shapes: {'raw_input': (21740, 300, 1), 'filtered_input': (21740, 300, 1), 'stft_input': (21740, 13, 1)}, labels=(21740,)
# Test data shapes: {'raw_input': (4250, 300, 1), 'filtered_input': (4250, 300, 1), 'stft_input': (4250, 13, 1)}, labels=(4250,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 55s 343ms/step - accuracy: 0.6337 - loss: 0.6433 - val_accuracy: 0.5754 - val_loss: 0.6584
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 38s 282ms/step - accuracy: 0.6429 - loss: 0.5835 - val_accuracy: 0.7790 - val_loss: 0.5140
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 41s 304ms/step - accuracy: 0.8133 - loss: 0.4447 - val_accuracy: 0.8034 - val_loss: 0.4719
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 40s 292ms/step - accuracy: 0.8587 - loss: 0.3491 - val_accuracy: 0.8804 - val_loss: 0.2839
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 269ms/step - accuracy: 0.8896 - loss: 0.2626 - val_accuracy: 0.8960 - val_loss: 0.2435
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 35s 260ms/step - accuracy: 0.9000 - loss: 0.2330 - val_accuracy: 0.9108 - val_loss: 0.2176
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 36s 262ms/step - accuracy: 0.9093 - loss: 0.2157 - val_accuracy: 0.9241 - val_loss: 0.1903
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 41s 303ms/step - accuracy: 0.9202 - loss: 0.1901 - val_accuracy: 0.9299 - val_loss: 0.1778
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 273ms/step - accuracy: 0.9271 - loss: 0.1789 - val_accuracy: 0.9312 - val_loss: 0.1736
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 36s 267ms/step - accuracy: 0.9310 - loss: 0.1718 - val_accuracy: 0.9319 - val_loss: 0.1714
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 269ms/step - accuracy: 0.9342 - loss: 0.1652 - val_accuracy: 0.9326 - val_loss: 0.1700
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 38s 279ms/step - accuracy: 0.9360 - loss: 0.1608 - val_accuracy: 0.9342 - val_loss: 0.1673
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 36s 263ms/step - accuracy: 0.9382 - loss: 0.1578 - val_accuracy: 0.9370 - val_loss: 0.1675
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 274ms/step - accuracy: 0.9412 - loss: 0.1532 - val_accuracy: 0.9372 - val_loss: 0.1651
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 268ms/step - accuracy: 0.9421 - loss: 0.1496 - val_accuracy: 0.9363 - val_loss: 0.1641
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 36s 267ms/step - accuracy: 0.9452 - loss: 0.1427 - val_accuracy: 0.9388 - val_loss: 0.1637
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 36s 264ms/step - accuracy: 0.9470 - loss: 0.1363 - val_accuracy: 0.9393 - val_loss: 0.1642
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 272ms/step - accuracy: 0.9503 - loss: 0.1289 - val_accuracy: 0.9379 - val_loss: 0.1675
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 269ms/step - accuracy: 0.9529 - loss: 0.1226 - val_accuracy: 0.9368 - val_loss: 0.1697
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 37s 269ms/step - accuracy: 0.9527 - loss: 0.1215 - val_accuracy: 0.9354 - val_loss: 0.1730
# Training finished.
# Evaluating on split_1's test data...
# Loss: 0.1328, Accuracy: 0.9471
# F1 Score for three_input_cnn on split_1: 0.9423
# Precision for three_input_cnn on split_1: 0.9411
# Recall for three_input_cnn on split_1: 0.9435
#
# --- Processing Split: split_2 ---
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 92 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 92 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Not setting metadata
# 21010 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 21010 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 4980 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 4980 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 21010 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 21010 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 4980 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 4980 events and 300 original time points ...
# 0 bad epochs dropped
#
# --- Evaluating Model: one_input_cnn on split_2 ---
# Training data shapes: (21010, 300, 1), labels=(21010,)
# Test data shapes: (4980, 300, 1), labels=(4980,)
# Building and compiling model...
# C:\Users\roseb\anaconda3\envs\msc_research_project\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Training the model...
# Epoch 1/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 21s 118ms/step - accuracy: 0.5596 - loss: 0.6873 - val_accuracy: 0.5607 - val_loss: 0.6844
# Epoch 2/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 113ms/step - accuracy: 0.5829 - loss: 0.6730 - val_accuracy: 0.7030 - val_loss: 0.6006
# Epoch 3/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.6259 - loss: 0.6480 - val_accuracy: 0.7120 - val_loss: 0.5794
# Epoch 4/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - accuracy: 0.6498 - loss: 0.5904 - val_accuracy: 0.5471 - val_loss: 0.6917
# Epoch 5/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 16s 118ms/step - accuracy: 0.5683 - loss: 0.6796 - val_accuracy: 0.5897 - val_loss: 0.6695
# Epoch 6/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - accuracy: 0.6259 - loss: 0.6450 - val_accuracy: 0.6287 - val_loss: 0.6695
# Epoch 7/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 116ms/step - accuracy: 0.7573 - loss: 0.4976 - val_accuracy: 0.7085 - val_loss: 0.5382
# Epoch 8/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - accuracy: 0.7679 - loss: 0.4767 - val_accuracy: 0.7620 - val_loss: 0.4831
# Epoch 9/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.8043 - loss: 0.4105 - val_accuracy: 0.7834 - val_loss: 0.4521
# Epoch 10/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - accuracy: 0.8227 - loss: 0.3797 - val_accuracy: 0.7925 - val_loss: 0.4444
# Epoch 11/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.8353 - loss: 0.3598 - val_accuracy: 0.8137 - val_loss: 0.4231
# Epoch 12/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 113ms/step - accuracy: 0.8476 - loss: 0.3355 - val_accuracy: 0.8406 - val_loss: 0.3819
# Epoch 13/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - accuracy: 0.8646 - loss: 0.3066 - val_accuracy: 0.8827 - val_loss: 0.2824
# Epoch 14/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.8694 - loss: 0.2936 - val_accuracy: 0.8836 - val_loss: 0.2794
# Epoch 15/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 117ms/step - accuracy: 0.8719 - loss: 0.2840 - val_accuracy: 0.8810 - val_loss: 0.2789
# Epoch 16/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 16s 121ms/step - accuracy: 0.8730 - loss: 0.2795 - val_accuracy: 0.8786 - val_loss: 0.2823
# Epoch 17/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 17s 126ms/step - accuracy: 0.8773 - loss: 0.2713 - val_accuracy: 0.8812 - val_loss: 0.2685
# Epoch 18/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 117ms/step - accuracy: 0.8818 - loss: 0.2672 - val_accuracy: 0.8824 - val_loss: 0.2676
# Epoch 19/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 16s 118ms/step - accuracy: 0.8823 - loss: 0.2647 - val_accuracy: 0.8817 - val_loss: 0.2689
# Epoch 20/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 116ms/step - accuracy: 0.8844 - loss: 0.2612 - val_accuracy: 0.8820 - val_loss: 0.2692
# Training finished.
# Evaluating on split_2's test data...
# Loss: 0.5850, Accuracy: 0.7329
# F1 Score for one_input_cnn on split_2: 0.7497
# Precision for one_input_cnn on split_2: 0.6033
# Recall for one_input_cnn on split_2: 0.9901
#
# --- Evaluating Model: two_input_cnn on split_2 ---
# Training data shapes: {'raw_input': (21010, 300, 1), 'filtered_input': (21010, 300, 1)}, labels=(21010,)
# Test data shapes: {'raw_input': (4980, 300, 1), 'filtered_input': (4980, 300, 1)}, labels=(4980,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 47s 307ms/step - accuracy: 0.6092 - loss: 0.6627 - val_accuracy: 0.5873 - val_loss: 0.6750
# Epoch 2/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 42s 315ms/step - accuracy: 0.6075 - loss: 0.6632 - val_accuracy: 0.6057 - val_loss: 0.6657
# Epoch 3/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 293ms/step - accuracy: 0.6248 - loss: 0.6500 - val_accuracy: 0.6435 - val_loss: 0.6423
# Epoch 4/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 297ms/step - accuracy: 0.7061 - loss: 0.5750 - val_accuracy: 0.7539 - val_loss: 0.4733
# Epoch 5/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 40s 300ms/step - accuracy: 0.8485 - loss: 0.3401 - val_accuracy: 0.7991 - val_loss: 0.3982
# Epoch 6/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - accuracy: 0.8920 - loss: 0.2587 - val_accuracy: 0.8977 - val_loss: 0.2572
# Epoch 7/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 38s 289ms/step - accuracy: 0.9117 - loss: 0.2192 - val_accuracy: 0.8232 - val_loss: 0.5635
# Epoch 8/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 38s 291ms/step - accuracy: 0.8536 - loss: 0.3848 - val_accuracy: 0.9224 - val_loss: 0.2142
# Epoch 9/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 0.9256 - loss: 0.2051 - val_accuracy: 0.9110 - val_loss: 0.2132
# Epoch 10/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 299ms/step - accuracy: 0.9323 - loss: 0.1747 - val_accuracy: 0.9279 - val_loss: 0.1922
# Epoch 11/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 0.9341 - loss: 0.1677 - val_accuracy: 0.9243 - val_loss: 0.1970
# Epoch 12/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 295ms/step - accuracy: 0.9307 - loss: 0.1766 - val_accuracy: 0.9357 - val_loss: 0.1772
# Epoch 13/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 40s 304ms/step - accuracy: 0.9371 - loss: 0.1615 - val_accuracy: 0.9181 - val_loss: 0.1923
# Epoch 14/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 0.9409 - loss: 0.1533 - val_accuracy: 0.9231 - val_loss: 0.1896
# Epoch 15/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 41s 314ms/step - accuracy: 0.9431 - loss: 0.1488 - val_accuracy: 0.9355 - val_loss: 0.1691
# Epoch 16/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 40s 305ms/step - accuracy: 0.9424 - loss: 0.1505 - val_accuracy: 0.9341 - val_loss: 0.1665
# Epoch 17/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 297ms/step - accuracy: 0.9458 - loss: 0.1405 - val_accuracy: 0.9305 - val_loss: 0.1789
# Epoch 18/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 294ms/step - accuracy: 0.9478 - loss: 0.1411 - val_accuracy: 0.9315 - val_loss: 0.1677
# Epoch 19/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 298ms/step - accuracy: 0.9457 - loss: 0.1462 - val_accuracy: 0.9327 - val_loss: 0.1764
# Epoch 20/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 284ms/step - accuracy: 0.9443 - loss: 0.1521 - val_accuracy: 0.9288 - val_loss: 0.1769
# Training finished.
# Evaluating on split_2's test data...
# Loss: 0.5366, Accuracy: 0.7954
# F1 Score for two_input_cnn on split_2: 0.7972
# Precision for two_input_cnn on split_2: 0.6648
# Recall for two_input_cnn on split_2: 0.9955
#
# --- Evaluating Model: three_input_cnn on split_2 ---
# Training data shapes: {'raw_input': (21010, 300, 1), 'filtered_input': (21010, 300, 1), 'stft_input': (21010, 13, 1)}, labels=(21010,)
# Test data shapes: {'raw_input': (4980, 300, 1), 'filtered_input': (4980, 300, 1), 'stft_input': (4980, 13, 1)}, labels=(4980,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 52s 327ms/step - accuracy: 0.6071 - loss: 0.6600 - val_accuracy: 0.5838 - val_loss: 0.6749
# Epoch 2/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 40s 301ms/step - accuracy: 0.7906 - loss: 0.4515 - val_accuracy: 0.5964 - val_loss: 0.6675
# Epoch 3/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 40s 299ms/step - accuracy: 0.6445 - loss: 0.6353 - val_accuracy: 0.8646 - val_loss: 0.3568
# Epoch 4/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 38s 284ms/step - accuracy: 0.8767 - loss: 0.3443 - val_accuracy: 0.8632 - val_loss: 0.3074
# Epoch 5/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 293ms/step - accuracy: 0.8387 - loss: 0.3585 - val_accuracy: 0.8855 - val_loss: 0.2757
# Epoch 6/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 39s 298ms/step - accuracy: 0.8983 - loss: 0.2492 - val_accuracy: 0.9048 - val_loss: 0.2261
# Epoch 7/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 38s 288ms/step - accuracy: 0.9151 - loss: 0.2088 - val_accuracy: 0.9062 - val_loss: 0.2217
# Epoch 8/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 278ms/step - accuracy: 0.9238 - loss: 0.2029 - val_accuracy: 0.8698 - val_loss: 0.3531
# Epoch 9/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 282ms/step - accuracy: 0.8951 - loss: 0.3137 - val_accuracy: 0.9241 - val_loss: 0.2269
# Epoch 10/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 282ms/step - accuracy: 0.8728 - loss: 0.3021 - val_accuracy: 0.6497 - val_loss: 0.6241
# Epoch 11/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 282ms/step - accuracy: 0.6552 - loss: 0.6206 - val_accuracy: 0.6713 - val_loss: 0.6016
# Epoch 12/20
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 277ms/step - accuracy: 0.7052 - loss: 0.5642 - val_accuracy: 0.8734 - val_loss: 0.3171
# Training finished.
# Evaluating on split_2's test data...
# Loss: 0.5123, Accuracy: 0.7795
# F1 Score for three_input_cnn on split_2: 0.7839
# Precision for three_input_cnn on split_2: 0.6490
# Recall for three_input_cnn on split_2: 0.9896
#
# --- Processing Split: split_3 ---
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 108 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 15 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 108 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 15 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Not setting metadata
# 20670 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 20670 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 5320 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5320 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 20670 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 20670 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 5320 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5320 events and 300 original time points ...
# 0 bad epochs dropped
#
# --- Evaluating Model: one_input_cnn on split_3 ---
# Training data shapes: (20670, 300, 1), labels=(20670,)
# Test data shapes: (5320, 300, 1), labels=(5320,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# C:\Users\roseb\anaconda3\envs\msc_research_project\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - accuracy: 0.5562 - loss: 0.6853 - val_accuracy: 0.5883 - val_loss: 0.6744
# Epoch 2/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - accuracy: 0.5959 - loss: 0.6674 - val_accuracy: 0.6534 - val_loss: 0.6306
# Epoch 3/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 15s 116ms/step - accuracy: 0.6432 - loss: 0.6220 - val_accuracy: 0.7755 - val_loss: 0.5001
# Epoch 4/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 15s 113ms/step - accuracy: 0.6467 - loss: 0.6105 - val_accuracy: 0.6998 - val_loss: 0.5966
# Epoch 5/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - accuracy: 0.7229 - loss: 0.5489 - val_accuracy: 0.8058 - val_loss: 0.4151
# Epoch 6/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 111ms/step - accuracy: 0.7949 - loss: 0.4317 - val_accuracy: 0.8365 - val_loss: 0.3687
# Epoch 7/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - accuracy: 0.8160 - loss: 0.3942 - val_accuracy: 0.8471 - val_loss: 0.3489
# Epoch 8/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - accuracy: 0.8317 - loss: 0.3599 - val_accuracy: 0.5764 - val_loss: 1.1775
# Epoch 9/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 109ms/step - accuracy: 0.7320 - loss: 0.5605 - val_accuracy: 0.8338 - val_loss: 0.3825
# Epoch 10/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 104ms/step - accuracy: 0.8317 - loss: 0.3649 - val_accuracy: 0.8096 - val_loss: 0.4042
# Epoch 11/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8347 - loss: 0.3608 - val_accuracy: 0.8754 - val_loss: 0.2943
# Epoch 12/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8564 - loss: 0.3172 - val_accuracy: 0.8936 - val_loss: 0.2536
# Epoch 13/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 15s 119ms/step - accuracy: 0.8671 - loss: 0.3001 - val_accuracy: 0.8909 - val_loss: 0.2582
# Epoch 14/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - accuracy: 0.8729 - loss: 0.2874 - val_accuracy: 0.8982 - val_loss: 0.2376
# Epoch 15/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - accuracy: 0.8783 - loss: 0.2769 - val_accuracy: 0.9013 - val_loss: 0.2284
# Epoch 16/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - accuracy: 0.8837 - loss: 0.2676 - val_accuracy: 0.9059 - val_loss: 0.2247
# Epoch 17/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.8854 - loss: 0.2604 - val_accuracy: 0.9061 - val_loss: 0.2235
# Epoch 18/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8878 - loss: 0.2560 - val_accuracy: 0.9083 - val_loss: 0.2211
# Epoch 19/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 14s 105ms/step - accuracy: 0.8918 - loss: 0.2493 - val_accuracy: 0.9105 - val_loss: 0.2219
# Epoch 20/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - accuracy: 0.8955 - loss: 0.2436 - val_accuracy: 0.9105 - val_loss: 0.2191
# Training finished.
# Evaluating on split_3's test data...
# Loss: 0.2672, Accuracy: 0.8893
# F1 Score for one_input_cnn on split_3: 0.8593
# Precision for one_input_cnn on split_3: 0.9193
# Recall for one_input_cnn on split_3: 0.8067
#
# --- Evaluating Model: two_input_cnn on split_3 ---
# Training data shapes: {'raw_input': (20670, 300, 1), 'filtered_input': (20670, 300, 1)}, labels=(20670,)
# Test data shapes: {'raw_input': (5320, 300, 1), 'filtered_input': (5320, 300, 1)}, labels=(5320,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 44s 289ms/step - accuracy: 0.6145 - loss: 0.6516 - val_accuracy: 0.6531 - val_loss: 0.6148
# Epoch 2/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 37s 283ms/step - accuracy: 0.7793 - loss: 0.4632 - val_accuracy: 0.7772 - val_loss: 0.4223
# Epoch 3/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 37s 283ms/step - accuracy: 0.8108 - loss: 0.4107 - val_accuracy: 0.8624 - val_loss: 0.3371
# Epoch 4/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 37s 288ms/step - accuracy: 0.8292 - loss: 0.3911 - val_accuracy: 0.8643 - val_loss: 0.3281
# Epoch 5/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 37s 286ms/step - accuracy: 0.8623 - loss: 0.3252 - val_accuracy: 0.8945 - val_loss: 0.2472
# Epoch 6/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 39s 297ms/step - accuracy: 0.8888 - loss: 0.2607 - val_accuracy: 0.9151 - val_loss: 0.2055
# Epoch 7/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 318ms/step - accuracy: 0.9037 - loss: 0.2341 - val_accuracy: 0.9192 - val_loss: 0.1911
# Epoch 8/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 39s 301ms/step - accuracy: 0.9077 - loss: 0.2182 - val_accuracy: 0.9214 - val_loss: 0.1957
# Epoch 9/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 38s 289ms/step - accuracy: 0.9082 - loss: 0.2157 - val_accuracy: 0.9299 - val_loss: 0.1772
# Epoch 10/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 38s 293ms/step - accuracy: 0.9167 - loss: 0.1960 - val_accuracy: 0.9311 - val_loss: 0.1746
# Epoch 11/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 37s 281ms/step - accuracy: 0.9227 - loss: 0.1859 - val_accuracy: 0.9328 - val_loss: 0.1721
# Epoch 12/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 38s 291ms/step - accuracy: 0.9265 - loss: 0.1796 - val_accuracy: 0.9344 - val_loss: 0.1712
# Epoch 13/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 39s 297ms/step - accuracy: 0.9303 - loss: 0.1746 - val_accuracy: 0.9369 - val_loss: 0.1670
# Epoch 14/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 37s 287ms/step - accuracy: 0.9317 - loss: 0.1712 - val_accuracy: 0.9393 - val_loss: 0.1656
# Epoch 15/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 36s 280ms/step - accuracy: 0.9341 - loss: 0.1666 - val_accuracy: 0.9369 - val_loss: 0.1702
# Epoch 16/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 38s 295ms/step - accuracy: 0.9330 - loss: 0.1673 - val_accuracy: 0.9395 - val_loss: 0.1635
# Epoch 17/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 272ms/step - accuracy: 0.9349 - loss: 0.1622 - val_accuracy: 0.9390 - val_loss: 0.1607
# Epoch 18/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 271ms/step - accuracy: 0.9374 - loss: 0.1591 - val_accuracy: 0.9395 - val_loss: 0.1624
# Epoch 19/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 37s 282ms/step - accuracy: 0.9385 - loss: 0.1560 - val_accuracy: 0.9395 - val_loss: 0.1587
# Epoch 20/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 36s 279ms/step - accuracy: 0.9305 - loss: 0.1858 - val_accuracy: 0.9390 - val_loss: 0.1640
# Training finished.
# Evaluating on split_3's test data...
# Loss: 0.1654, Accuracy: 0.9374
# F1 Score for two_input_cnn on split_3: 0.9236
# Precision for two_input_cnn on split_3: 0.9459
# Recall for two_input_cnn on split_3: 0.9022
#
# --- Evaluating Model: three_input_cnn on split_3 ---
# Training data shapes: {'raw_input': (20670, 300, 1), 'filtered_input': (20670, 300, 1), 'stft_input': (20670, 13, 1)}, labels=(20670,)
# Test data shapes: {'raw_input': (5320, 300, 1), 'filtered_input': (5320, 300, 1), 'stft_input': (5320, 13, 1)}, labels=(5320,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 50s 322ms/step - accuracy: 0.6132 - loss: 0.6466 - val_accuracy: 0.6604 - val_loss: 0.7859
# Epoch 2/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 268ms/step - accuracy: 0.7711 - loss: 0.5238 - val_accuracy: 0.8503 - val_loss: 0.4014
# Epoch 3/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 36s 278ms/step - accuracy: 0.8365 - loss: 0.4362 - val_accuracy: 0.8420 - val_loss: 0.3851
# Epoch 4/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 267ms/step - accuracy: 0.7179 - loss: 0.5466 - val_accuracy: 0.6468 - val_loss: 0.6431
# Epoch 5/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 267ms/step - accuracy: 0.6495 - loss: 0.6302 - val_accuracy: 0.8442 - val_loss: 0.3657
# Epoch 6/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 260ms/step - accuracy: 0.8548 - loss: 0.3369 - val_accuracy: 0.9059 - val_loss: 0.2191
# Epoch 7/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 267ms/step - accuracy: 0.8985 - loss: 0.2436 - val_accuracy: 0.9224 - val_loss: 0.1935
# Epoch 8/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 260ms/step - accuracy: 0.9175 - loss: 0.2052 - val_accuracy: 0.9299 - val_loss: 0.1814
# Epoch 9/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 265ms/step - accuracy: 0.9264 - loss: 0.1868 - val_accuracy: 0.9325 - val_loss: 0.1740
# Epoch 10/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 263ms/step - accuracy: 0.9301 - loss: 0.1746 - val_accuracy: 0.9378 - val_loss: 0.1645
# Epoch 11/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 264ms/step - accuracy: 0.9334 - loss: 0.1645 - val_accuracy: 0.9403 - val_loss: 0.1590
# Epoch 12/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 263ms/step - accuracy: 0.9364 - loss: 0.1567 - val_accuracy: 0.9422 - val_loss: 0.1542
# Epoch 13/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 262ms/step - accuracy: 0.9387 - loss: 0.1505 - val_accuracy: 0.9441 - val_loss: 0.1505
# Epoch 14/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 259ms/step - accuracy: 0.9416 - loss: 0.1450 - val_accuracy: 0.9446 - val_loss: 0.1491
# Epoch 15/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 261ms/step - accuracy: 0.9448 - loss: 0.1406 - val_accuracy: 0.9448 - val_loss: 0.1465
# Epoch 16/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 267ms/step - accuracy: 0.9468 - loss: 0.1364 - val_accuracy: 0.9444 - val_loss: 0.1472
# Epoch 17/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 268ms/step - accuracy: 0.9478 - loss: 0.1329 - val_accuracy: 0.9441 - val_loss: 0.1470
# Epoch 18/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 263ms/step - accuracy: 0.9502 - loss: 0.1289 - val_accuracy: 0.9434 - val_loss: 0.1490
# Epoch 19/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 35s 269ms/step - accuracy: 0.9494 - loss: 0.1251 - val_accuracy: 0.9422 - val_loss: 0.1537
# Epoch 20/20
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 34s 263ms/step - accuracy: 0.9503 - loss: 0.1207 - val_accuracy: 0.9398 - val_loss: 0.1609
# Training finished.
# Evaluating on split_3's test data...
# Loss: 0.1671, Accuracy: 0.9353
# F1 Score for three_input_cnn on split_3: 0.9200
# Precision for three_input_cnn on split_3: 0.9556
# Recall for three_input_cnn on split_3: 0.8870
#
# --- Processing Split: split_4 ---
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 91 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 32 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 91 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 32 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Not setting metadata
# 20420 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 20420 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 5570 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5570 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 20420 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 20420 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 5570 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5570 events and 300 original time points ...
# 0 bad epochs dropped
#
# --- Evaluating Model: one_input_cnn on split_4 ---
# Training data shapes: (20420, 300, 1), labels=(20420,)
# Test data shapes: (5570, 300, 1), labels=(5570,)
# Building and compiling model...
# C:\Users\roseb\anaconda3\envs\msc_research_project\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Training the model...
# Epoch 1/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 117ms/step - accuracy: 0.5512 - loss: 0.6875 - val_accuracy: 0.6033 - val_loss: 0.6721
# Epoch 2/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - accuracy: 0.5900 - loss: 0.6682 - val_accuracy: 0.5874 - val_loss: 0.6667
# Epoch 3/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 109ms/step - accuracy: 0.6054 - loss: 0.6501 - val_accuracy: 0.6885 - val_loss: 0.6026
# Epoch 4/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - accuracy: 0.6758 - loss: 0.6060 - val_accuracy: 0.7400 - val_loss: 0.5348
# Epoch 5/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 109ms/step - accuracy: 0.7089 - loss: 0.5722 - val_accuracy: 0.7667 - val_loss: 0.4989
# Epoch 6/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - accuracy: 0.7698 - loss: 0.4803 - val_accuracy: 0.7801 - val_loss: 0.4947
# Epoch 7/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - accuracy: 0.7836 - loss: 0.4564 - val_accuracy: 0.8310 - val_loss: 0.3696
# Epoch 8/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - accuracy: 0.8275 - loss: 0.3775 - val_accuracy: 0.8355 - val_loss: 0.3871
# Epoch 9/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - accuracy: 0.8511 - loss: 0.3365 - val_accuracy: 0.8763 - val_loss: 0.2796
# Epoch 10/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - accuracy: 0.8610 - loss: 0.3147 - val_accuracy: 0.8879 - val_loss: 0.2607
# Epoch 11/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - accuracy: 0.8676 - loss: 0.2999 - val_accuracy: 0.8876 - val_loss: 0.2597
# Epoch 12/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - accuracy: 0.8765 - loss: 0.2870 - val_accuracy: 0.8962 - val_loss: 0.2362
# Epoch 13/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - accuracy: 0.8784 - loss: 0.2790 - val_accuracy: 0.8896 - val_loss: 0.2558
# Epoch 14/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - accuracy: 0.8815 - loss: 0.2743 - val_accuracy: 0.8937 - val_loss: 0.2487
# Epoch 15/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - accuracy: 0.8825 - loss: 0.2707 - val_accuracy: 0.9045 - val_loss: 0.2252
# Epoch 16/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - accuracy: 0.8814 - loss: 0.2698 - val_accuracy: 0.9003 - val_loss: 0.2289
# Epoch 17/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 109ms/step - accuracy: 0.8851 - loss: 0.2642 - val_accuracy: 0.9082 - val_loss: 0.2193
# Epoch 18/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - accuracy: 0.8871 - loss: 0.2582 - val_accuracy: 0.9114 - val_loss: 0.2145
# Epoch 19/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - accuracy: 0.8900 - loss: 0.2578 - val_accuracy: 0.9128 - val_loss: 0.2107
# Epoch 20/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - accuracy: 0.8927 - loss: 0.2529 - val_accuracy: 0.9128 - val_loss: 0.2090
# Training finished.
# Evaluating on split_4's test data...
# Loss: 0.3137, Accuracy: 0.8718
# F1 Score for one_input_cnn on split_4: 0.8450
# Precision for one_input_cnn on split_4: 0.9392
# Recall for one_input_cnn on split_4: 0.7680
#
# --- Evaluating Model: two_input_cnn on split_4 ---
# Training data shapes: {'raw_input': (20420, 300, 1), 'filtered_input': (20420, 300, 1)}, labels=(20420,)
# Test data shapes: {'raw_input': (5570, 300, 1), 'filtered_input': (5570, 300, 1)}, labels=(5570,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 51s 347ms/step - accuracy: 0.5938 - loss: 0.6687 - val_accuracy: 0.5884 - val_loss: 0.6810
# Epoch 2/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 37s 287ms/step - accuracy: 0.6013 - loss: 0.6664 - val_accuracy: 0.6655 - val_loss: 0.6248
# Epoch 3/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 37s 288ms/step - accuracy: 0.6608 - loss: 0.5810 - val_accuracy: 0.7654 - val_loss: 0.4734
# Epoch 4/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 37s 292ms/step - accuracy: 0.8135 - loss: 0.4187 - val_accuracy: 0.8646 - val_loss: 0.3274
# Epoch 5/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 37s 288ms/step - accuracy: 0.8031 - loss: 0.4292 - val_accuracy: 0.8421 - val_loss: 0.3712
# Epoch 6/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 36s 284ms/step - accuracy: 0.8593 - loss: 0.3222 - val_accuracy: 0.8969 - val_loss: 0.2318
# Epoch 7/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 38s 293ms/step - accuracy: 0.9066 - loss: 0.2237 - val_accuracy: 0.9119 - val_loss: 0.2017
# Epoch 8/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 39s 305ms/step - accuracy: 0.9202 - loss: 0.1943 - val_accuracy: 0.9295 - val_loss: 0.1736
# Epoch 9/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 37s 292ms/step - accuracy: 0.9267 - loss: 0.1815 - val_accuracy: 0.9346 - val_loss: 0.1623
# Epoch 10/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 37s 292ms/step - accuracy: 0.9297 - loss: 0.1725 - val_accuracy: 0.9358 - val_loss: 0.1565
# Epoch 11/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 37s 292ms/step - accuracy: 0.9342 - loss: 0.1650 - val_accuracy: 0.9388 - val_loss: 0.1512
# Epoch 12/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 39s 305ms/step - accuracy: 0.9377 - loss: 0.1591 - val_accuracy: 0.9417 - val_loss: 0.1471
# Epoch 13/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 38s 294ms/step - accuracy: 0.9401 - loss: 0.1540 - val_accuracy: 0.9432 - val_loss: 0.1445
# Epoch 14/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 36s 283ms/step - accuracy: 0.9412 - loss: 0.1497 - val_accuracy: 0.9447 - val_loss: 0.1419
# Epoch 15/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 38s 297ms/step - accuracy: 0.9419 - loss: 0.1461 - val_accuracy: 0.9452 - val_loss: 0.1417
# Epoch 16/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 42s 328ms/step - accuracy: 0.9427 - loss: 0.1428 - val_accuracy: 0.9456 - val_loss: 0.1403
# Epoch 17/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 53s 415ms/step - accuracy: 0.9438 - loss: 0.1392 - val_accuracy: 0.9447 - val_loss: 0.1397
# Epoch 18/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 53s 412ms/step - accuracy: 0.9446 - loss: 0.1358 - val_accuracy: 0.9459 - val_loss: 0.1397
# Epoch 19/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 53s 414ms/step - accuracy: 0.9457 - loss: 0.1332 - val_accuracy: 0.9464 - val_loss: 0.1391
# Epoch 20/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 50s 391ms/step - accuracy: 0.9466 - loss: 0.1304 - val_accuracy: 0.9461 - val_loss: 0.1396
# Training finished.
# Evaluating on split_4's test data...
# Loss: 0.2797, Accuracy: 0.9045
# F1 Score for two_input_cnn on split_4: 0.8880
# Precision for two_input_cnn on split_4: 0.9513
# Recall for two_input_cnn on split_4: 0.8327
#
# --- Evaluating Model: three_input_cnn on split_4 ---
# Training data shapes: {'raw_input': (20420, 300, 1), 'filtered_input': (20420, 300, 1), 'stft_input': (20420, 13, 1)}, labels=(20420,)
# Test data shapes: {'raw_input': (5570, 300, 1), 'filtered_input': (5570, 300, 1), 'stft_input': (5570, 13, 1)}, labels=(5570,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 61s 362ms/step - accuracy: 0.6099 - loss: 0.6548 - val_accuracy: 0.5441 - val_loss: 0.6712
# Epoch 2/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 42s 328ms/step - accuracy: 0.7707 - loss: 0.4603 - val_accuracy: 0.8421 - val_loss: 0.3752
# Epoch 3/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 42s 327ms/step - accuracy: 0.8595 - loss: 0.3150 - val_accuracy: 0.9028 - val_loss: 0.2429
# Epoch 4/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 43s 339ms/step - accuracy: 0.8959 - loss: 0.2482 - val_accuracy: 0.9116 - val_loss: 0.2378
# Epoch 5/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 41s 317ms/step - accuracy: 0.8617 - loss: 0.3375 - val_accuracy: 0.8783 - val_loss: 0.3157
# Epoch 6/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 40s 312ms/step - accuracy: 0.8772 - loss: 0.3222 - val_accuracy: 0.9236 - val_loss: 0.2085
# Epoch 7/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 40s 313ms/step - accuracy: 0.9064 - loss: 0.2430 - val_accuracy: 0.9160 - val_loss: 0.2402
# Epoch 8/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 40s 312ms/step - accuracy: 0.9072 - loss: 0.2366 - val_accuracy: 0.9317 - val_loss: 0.1738
# Epoch 9/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 40s 311ms/step - accuracy: 0.9043 - loss: 0.2690 - val_accuracy: 0.9221 - val_loss: 0.1899
# Epoch 10/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - accuracy: 0.9256 - loss: 0.1909 - val_accuracy: 0.9361 - val_loss: 0.1708
# Epoch 11/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 40s 315ms/step - accuracy: 0.9155 - loss: 0.2071 - val_accuracy: 0.8168 - val_loss: 0.3995
# Epoch 12/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 40s 312ms/step - accuracy: 0.8272 - loss: 0.3852 - val_accuracy: 0.8761 - val_loss: 0.2780
# Epoch 13/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 39s 306ms/step - accuracy: 0.8683 - loss: 0.2944 - val_accuracy: 0.9033 - val_loss: 0.2284
# Epoch 14/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 44s 340ms/step - accuracy: 0.8969 - loss: 0.2418 - val_accuracy: 0.9167 - val_loss: 0.1979
# Epoch 15/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 40s 309ms/step - accuracy: 0.9135 - loss: 0.2098 - val_accuracy: 0.9275 - val_loss: 0.1820
# Training finished.
# Evaluating on split_4's test data...
# Loss: 0.2315, Accuracy: 0.9136
# F1 Score for three_input_cnn on split_4: 0.9014
# Precision for three_input_cnn on split_4: 0.9381
# Recall for three_input_cnn on split_4: 0.8674
#
# --- Processing Split: split_5 ---
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 105 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 105 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Not setting metadata
# 20120 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 20120 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 5870 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5870 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 20120 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 20120 events and 300 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 5870 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5870 events and 300 original time points ...
# 0 bad epochs dropped
#
# --- Evaluating Model: one_input_cnn on split_5 ---
# Training data shapes: (20120, 300, 1), labels=(20120,)
# Test data shapes: (5870, 300, 1), labels=(5870,)
# Building and compiling model...
# C:\Users\roseb\anaconda3\envs\msc_research_project\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Training the model...
# Epoch 1/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 27s 172ms/step - accuracy: 0.5499 - loss: 0.6862 - val_accuracy: 0.6260 - val_loss: 0.6614
# Epoch 2/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - accuracy: 0.6053 - loss: 0.6662 - val_accuracy: 0.7209 - val_loss: 0.5866
# Epoch 3/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.6178 - loss: 0.6469 - val_accuracy: 0.6879 - val_loss: 0.5652
# Epoch 4/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - accuracy: 0.6357 - loss: 0.6329 - val_accuracy: 0.7520 - val_loss: 0.5102
# Epoch 5/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 154ms/step - accuracy: 0.6788 - loss: 0.6001 - val_accuracy: 0.7122 - val_loss: 0.5639
# Epoch 6/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - accuracy: 0.7221 - loss: 0.5468 - val_accuracy: 0.7751 - val_loss: 0.5056
# Epoch 7/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.7846 - loss: 0.4547 - val_accuracy: 0.7853 - val_loss: 0.5108
# Epoch 8/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - accuracy: 0.7998 - loss: 0.4288 - val_accuracy: 0.8243 - val_loss: 0.4102
# Epoch 9/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - accuracy: 0.8122 - loss: 0.4100 - val_accuracy: 0.8551 - val_loss: 0.3329
# Epoch 10/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - accuracy: 0.8297 - loss: 0.3780 - val_accuracy: 0.8626 - val_loss: 0.3143
# Epoch 11/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - accuracy: 0.8357 - loss: 0.3599 - val_accuracy: 0.8735 - val_loss: 0.2930
# Epoch 12/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - accuracy: 0.8471 - loss: 0.3397 - val_accuracy: 0.8760 - val_loss: 0.2775
# Epoch 13/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.8532 - loss: 0.3300 - val_accuracy: 0.8802 - val_loss: 0.2659
# Epoch 14/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.8604 - loss: 0.3160 - val_accuracy: 0.8907 - val_loss: 0.2490
# Epoch 15/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 152ms/step - accuracy: 0.8686 - loss: 0.2998 - val_accuracy: 0.8931 - val_loss: 0.2435
# Epoch 16/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - accuracy: 0.8782 - loss: 0.2877 - val_accuracy: 0.8931 - val_loss: 0.2383
# Epoch 17/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - accuracy: 0.8817 - loss: 0.2780 - val_accuracy: 0.8956 - val_loss: 0.2355
# Epoch 18/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.8867 - loss: 0.2714 - val_accuracy: 0.8961 - val_loss: 0.2332
# Epoch 19/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 146ms/step - accuracy: 0.8891 - loss: 0.2662 - val_accuracy: 0.8959 - val_loss: 0.2330
# Epoch 20/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 17s 138ms/step - accuracy: 0.8888 - loss: 0.2623 - val_accuracy: 0.8951 - val_loss: 0.2324
# Training finished.
# Evaluating on split_5's test data...
# Loss: 0.3274, Accuracy: 0.8569
# F1 Score for one_input_cnn on split_5: 0.8477
# Precision for one_input_cnn on split_5: 0.8048
# Recall for one_input_cnn on split_5: 0.8954
#
# --- Evaluating Model: two_input_cnn on split_5 ---
# Training data shapes: {'raw_input': (20120, 300, 1), 'filtered_input': (20120, 300, 1)}, labels=(20120,)
# Test data shapes: {'raw_input': (5870, 300, 1), 'filtered_input': (5870, 300, 1)}, labels=(5870,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 45s 308ms/step - accuracy: 0.6244 - loss: 0.6497 - val_accuracy: 0.6143 - val_loss: 0.6990
# Epoch 2/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 33s 261ms/step - accuracy: 0.5717 - loss: 0.6820 - val_accuracy: 0.6325 - val_loss: 0.6529
# Epoch 3/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 33s 259ms/step - accuracy: 0.6462 - loss: 0.6322 - val_accuracy: 0.8745 - val_loss: 0.2875
# Epoch 4/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 33s 260ms/step - accuracy: 0.8626 - loss: 0.3137 - val_accuracy: 0.8929 - val_loss: 0.2340
# Epoch 5/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 34s 270ms/step - accuracy: 0.9001 - loss: 0.2389 - val_accuracy: 0.9361 - val_loss: 0.1574
# Epoch 6/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 32s 257ms/step - accuracy: 0.9258 - loss: 0.1920 - val_accuracy: 0.9406 - val_loss: 0.1477
# Epoch 7/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 33s 261ms/step - accuracy: 0.9286 - loss: 0.1812 - val_accuracy: 0.9446 - val_loss: 0.1421
# Epoch 8/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 32s 258ms/step - accuracy: 0.9335 - loss: 0.1727 - val_accuracy: 0.9426 - val_loss: 0.1393
# Epoch 9/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 33s 260ms/step - accuracy: 0.9371 - loss: 0.1670 - val_accuracy: 0.9423 - val_loss: 0.1368
# Epoch 10/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 33s 259ms/step - accuracy: 0.9396 - loss: 0.1624 - val_accuracy: 0.9426 - val_loss: 0.1358
# Epoch 11/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - accuracy: 0.9413 - loss: 0.1584 - val_accuracy: 0.9436 - val_loss: 0.1357
# Epoch 12/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 51s 407ms/step - accuracy: 0.9428 - loss: 0.1551 - val_accuracy: 0.9456 - val_loss: 0.1354
# Epoch 13/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 52s 410ms/step - accuracy: 0.9430 - loss: 0.1521 - val_accuracy: 0.9463 - val_loss: 0.1358
# Epoch 14/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 51s 406ms/step - accuracy: 0.9446 - loss: 0.1494 - val_accuracy: 0.9453 - val_loss: 0.1371
# Epoch 15/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 53s 419ms/step - accuracy: 0.9447 - loss: 0.1471 - val_accuracy: 0.9451 - val_loss: 0.1378
# Epoch 16/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 52s 410ms/step - accuracy: 0.9445 - loss: 0.1450 - val_accuracy: 0.9456 - val_loss: 0.1380
# Epoch 17/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 53s 419ms/step - accuracy: 0.9456 - loss: 0.1425 - val_accuracy: 0.9443 - val_loss: 0.1396
# Training finished.
# Evaluating on split_5's test data...
# Loss: 0.1854, Accuracy: 0.9262
# F1 Score for two_input_cnn on split_5: 0.9140
# Precision for two_input_cnn on split_5: 0.9489
# Recall for two_input_cnn on split_5: 0.8816
#
# --- Evaluating Model: three_input_cnn on split_5 ---
# Training data shapes: {'raw_input': (20120, 300, 1), 'filtered_input': (20120, 300, 1), 'stft_input': (20120, 13, 1)}, labels=(20120,)
# Test data shapes: {'raw_input': (5870, 300, 1), 'filtered_input': (5870, 300, 1), 'stft_input': (5870, 13, 1)}, labels=(5870,)
# Building and compiling model...
# Training the model...
# Epoch 1/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 85s 527ms/step - accuracy: 0.6418 - loss: 0.6300 - val_accuracy: 0.6869 - val_loss: 0.6294
# Epoch 2/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 58s 462ms/step - accuracy: 0.7189 - loss: 0.5575 - val_accuracy: 0.6474 - val_loss: 0.6341
# Epoch 3/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 58s 457ms/step - accuracy: 0.6332 - loss: 0.6375 - val_accuracy: 0.6578 - val_loss: 0.6157
# Epoch 4/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 439ms/step - accuracy: 0.7375 - loss: 0.5282 - val_accuracy: 0.8792 - val_loss: 0.2694
# Epoch 5/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 436ms/step - accuracy: 0.8627 - loss: 0.3127 - val_accuracy: 0.9145 - val_loss: 0.1993
# Epoch 6/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 54s 432ms/step - accuracy: 0.8917 - loss: 0.2515 - val_accuracy: 0.9292 - val_loss: 0.1714
# Epoch 7/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 435ms/step - accuracy: 0.9138 - loss: 0.2111 - val_accuracy: 0.9334 - val_loss: 0.1647
# Epoch 8/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 434ms/step - accuracy: 0.9220 - loss: 0.1984 - val_accuracy: 0.9336 - val_loss: 0.1615
# Epoch 9/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 435ms/step - accuracy: 0.9240 - loss: 0.1906 - val_accuracy: 0.9381 - val_loss: 0.1546
# Epoch 10/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 442ms/step - accuracy: 0.9274 - loss: 0.1823 - val_accuracy: 0.9409 - val_loss: 0.1486
# Epoch 11/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 445ms/step - accuracy: 0.9303 - loss: 0.1750 - val_accuracy: 0.9431 - val_loss: 0.1444
# Epoch 12/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 433ms/step - accuracy: 0.9342 - loss: 0.1683 - val_accuracy: 0.9438 - val_loss: 0.1402
# Epoch 13/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 436ms/step - accuracy: 0.9377 - loss: 0.1617 - val_accuracy: 0.9453 - val_loss: 0.1375
# Epoch 14/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 436ms/step - accuracy: 0.9410 - loss: 0.1552 - val_accuracy: 0.9453 - val_loss: 0.1353
# Epoch 15/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 54s 432ms/step - accuracy: 0.9440 - loss: 0.1484 - val_accuracy: 0.9471 - val_loss: 0.1338
# Epoch 16/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 54s 432ms/step - accuracy: 0.9469 - loss: 0.1418 - val_accuracy: 0.9473 - val_loss: 0.1329
# Epoch 17/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 54s 432ms/step - accuracy: 0.9485 - loss: 0.1354 - val_accuracy: 0.9476 - val_loss: 0.1344
# Epoch 18/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 433ms/step - accuracy: 0.9508 - loss: 0.1293 - val_accuracy: 0.9463 - val_loss: 0.1356
# Epoch 19/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 432ms/step - accuracy: 0.9525 - loss: 0.1237 - val_accuracy: 0.9458 - val_loss: 0.1384
# Epoch 20/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 439ms/step - accuracy: 0.9547 - loss: 0.1172 - val_accuracy: 0.9443 - val_loss: 0.1415
# Training finished.
# Evaluating on split_5's test data...
# Loss: 0.1742, Accuracy: 0.9354
# F1 Score for three_input_cnn on split_5: 0.9266
# Precision for three_input_cnn on split_5: 0.9369
# Recall for three_input_cnn on split_5: 0.9165
#
# --- Evaluation finished for all models across all splits ---

# %% [markdown]
# ## Display average metrics and statistics

# %%
# display F1, precision and recall in a data frame

rows = []

for model_name, metrics in model_metrics.items():
    average_f1 = np.mean(metrics['f1_scores'])
    std_f1 = np.std(metrics['f1_scores'])

    average_precision = np.mean(metrics['precision_scores'])
    std_precision = np.std(metrics['precision_scores'])

    average_recall = np.mean(metrics['recall_scores'])
    std_recall = np.std(metrics['recall_scores'])

    # the row is appended as a dict
    rows.append({
        "Model": model_name,
        "F1 Score (mean ± std)": f"{average_f1:.4f} ± {std_f1:.4f}",
        "Precision (mean ± std)": f"{average_precision:.4f} ± {std_precision:.4f}",
        "Recall (mean ± std)": f"{average_recall:.4f} ± {std_recall:.4f}",
    })

# use pandas to create the data frame
summary_df = pd.DataFrame(rows)

# add a title and print the table
print("\n--- Average Metrics Across Splits For Spindle Detection ---\n")
print(summary_df.to_string(index=False))


# add statistics

# definition
def compare_models(f1_a, f1_b, model_a_name, model_b_name, alpha=0.05, n_comparisons=1):
    # first alpha is adjusted for multiple comparisons
    corrected_alpha = alpha / n_comparisons
    print(f"\nBonferroni corrected alpha: {corrected_alpha:.4f} (original alpha={alpha} / {n_comparisons} comparisons)")

    # differences computed
    diff = np.array(f1_b) - np.array(f1_a)

    # plot distribution to assess normality
    plt.figure(figsize=(6, 4))
    sns.histplot(diff, kde=True, bins=8)
    plt.title(f'Distribution of F1 Score Differences: {model_b_name} - {model_a_name}')
    plt.xlabel('F1 Score Difference')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # shapiro wilk test to assess normality
    # determines which type of t-test to do
    w_stat, p_norm = shapiro(diff)
    print(f"Shapiro-Wilk normality test: W = {w_stat:.4f}, p = {p_norm:.4f}")

    # then perform t-test (paired t-test or wilcoxon signed-rank test)
    print(f"\n--- Statistical Comparison: {model_b_name} vs {model_a_name} ---")
    if p_norm > corrected_alpha:
        print("Paired t-test (normal distribution)")
        t_stat, p_val = ttest_rel(f1_b, f1_a)
        print(f"t-statistic = {t_stat:.4f}, p-value = {p_val:.4f}")
    else:
        print("Wilcoxon signed-rank test (non-normal distribution)")
        w_stat, p_val = wilcoxon(f1_b, f1_a)
        print(f"W-statistic = {w_stat:.4f}, p-value = {p_val:.4f}")

    # then compare with the Bonferroni corrected alpha
    if p_val < corrected_alpha:
        print(f"Significant difference at corrected alpha = {corrected_alpha:.4f}")
    else:
        print(f"No significant difference at corrected alpha = {corrected_alpha:.4f}")

# then do the three model comparisons

compare_models(
    f1_a=model_metrics['one_input_cnn']['f1_scores'],
    f1_b=model_metrics['two_input_cnn']['f1_scores'],
    model_a_name='one_input_cnn',
    model_b_name='two_input_cnn',
    alpha=0.05,
    n_comparisons=3
)

compare_models(
    f1_a=model_metrics['one_input_cnn']['f1_scores'],
    f1_b=model_metrics['three_input_cnn']['f1_scores'],
    model_a_name='one_input_cnn',
    model_b_name='three_input_cnn',
    alpha=0.05,
    n_comparisons=3
)

compare_models(
    f1_a=model_metrics['two_input_cnn']['f1_scores'],
    f1_b=model_metrics['three_input_cnn']['f1_scores'],
    model_a_name='two_input_cnn',
    model_b_name='three_input_cnn',
    alpha=0.05,
    n_comparisons=3
)
# Out:
# --- Average Metrics Across Splits For Spindle Detection ---
#
#           Model F1 Score (mean ± std) Precision (mean ± std) Recall (mean ± std)
#   one_input_cnn       0.8247 ± 0.0394        0.8220 ± 0.1198     0.8524 ± 0.0807
#   two_input_cnn       0.8932 ± 0.0512        0.8883 ± 0.1120     0.9137 ± 0.0570
# three_input_cnn       0.8948 ± 0.0570        0.8841 ± 0.1178     0.9208 ± 0.0430
#
# Bonferroni corrected alpha: 0.0167 (original alpha=0.05 / 3 comparisons)
# Shapiro-Wilk normality test: W = 0.8203, p = 0.1174
#
# --- Statistical Comparison: two_input_cnn vs one_input_cnn ---
# Paired t-test (normal distribution)
# t-statistic = 4.9079, p-value = 0.0080
# Significant difference at corrected alpha = 0.0167
#
# Bonferroni corrected alpha: 0.0167 (original alpha=0.05 / 3 comparisons)
# Shapiro-Wilk normality test: W = 0.9434, p = 0.6904
#
# --- Statistical Comparison: three_input_cnn vs one_input_cnn ---
# Paired t-test (normal distribution)
# t-statistic = 4.8558, p-value = 0.0083
# Significant difference at corrected alpha = 0.0167
#
# Bonferroni corrected alpha: 0.0167 (original alpha=0.05 / 3 comparisons)
# Shapiro-Wilk normality test: W = 0.9083, p = 0.4574
#
# --- Statistical Comparison: three_input_cnn vs two_input_cnn ---
# Paired t-test (normal distribution)
# t-statistic = 0.3160, p-value = 0.7678
# No significant difference at corrected alpha = 0.0167

# %%
# this is to get nicer visualisations

# have a table only with F1 scores
model_names = list(model_metrics.keys())
average_f1s = [round(np.mean(model_metrics[name]['f1_scores']), 2) for name in model_names]
std_f1s = [round(np.std(model_metrics[name]['f1_scores']), 2) for name in model_names]

summary_data = {
    'Model': model_names,
    'Mean F1 Score': average_f1s,
    'F1 Score Std Dev': std_f1s
}
summary_df = pd.DataFrame(summary_data)

print("\n--- Summary of F1 Scores Across 5 Folds for Spindle Detection ---")
display(summary_df)

# create bar plot with F1 score for each model
plt.figure(figsize=(10, 6))
bars = plt.bar(summary_df['Model'], summary_df['Mean F1 Score'],
               yerr=summary_df['F1 Score Std Dev'], capsize=5,
               color=['lightcoral', 'lightgreen', 'skyblue'])

# the F1 values are on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.01, f'{yval:.2f}', va='bottom', ha='center', fontsize=10)

plt.ylabel("Mean F1 Score")
plt.title("Comparison of Model Performance on Spindle Detection for 5 participants")
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
# Out:
# --- Summary of F1 Scores Across 5 Folds for Spindle Detection ---
#              Model  Mean F1 Score  F1 Score Std Dev
# 0    one_input_cnn           0.82              0.04
# 1    two_input_cnn           0.89              0.05
# 2  three_input_cnn           0.89              0.06
