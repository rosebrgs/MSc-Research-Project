# %%
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import mne
import matplotlib.pyplot as plt
import pyvista
import ipywidgets
import ipyevents
import pyvistaqt
import yasa
import os
import random

import scipy.signal as signal
from scipy.signal import hilbert
from scipy.signal import stft
from scipy.interpolate import interpn

import pywt
import cv2

# %%
# %matplotlib qt

# %% [markdown]
# ## Importing data

# %%
participant_ids = ['013', '014', '018', '019', '020', '022', '023', '024', '025','027', '028', '029', '030', '031', '032', '033', '034',
                   '035', '036', '037',  '042',  '044','046', '047', '048', '049', '050', '051', '052', '053', '054','055', '056', '057', 
                   '058', '059', '060', '061', '064','066', '067', '068', '070', '071', '072', '074', '075', '076', '077', '078', '080', '081', '082']

combined_raw_data = {}
# will store the raw objects in a dictionary
base_path = r"C:\eeg"

# for loop through the participants to load the data
for pid in participant_ids:
    file_path = fr"{base_path}\{pid}\concatenated\{pid}_concatenated_raw.fif"
    combined_raw_data[pid] = mne.io.read_raw_fif(file_path, preload=True)

# if want to access participant 067
# raw_067 = combined_raw_data["067"]
# Out:
# Opening raw data file C:\eeg\013\concatenated\013_concatenated_raw.fif...
# Isotrak not found
#     Range : 855000 ... 6750021 =   1710.000 ... 13500.042 secs
# Ready.
# Reading 0 ... 5895021  =      0.000 ... 11790.042 secs...
# Opening raw data file C:\eeg\014\concatenated\014_concatenated_raw.fif...
# Isotrak not found
#     Range : 330000 ... 6540021 =    660.000 ... 13080.042 secs
# Ready.
# Reading 0 ... 6210021  =      0.000 ... 12420.042 secs...
# Opening raw data file C:\eeg\018\concatenated\018_concatenated_raw.fif...
# Isotrak not found
#     Range : 435000 ... 8295022 =    870.000 ... 16590.044 secs
# Ready.
# Reading 0 ... 7860022  =      0.000 ... 15720.044 secs...
# Opening raw data file C:\eeg\019\concatenated\019_concatenated_raw.fif...
# Isotrak not found
#     Range : 675000 ... 6795017 =   1350.000 ... 13590.034 secs
# Ready.
# Reading 0 ... 6120017  =      0.000 ... 12240.034 secs...
# Opening raw data file C:\eeg\020\concatenated\020_concatenated_raw.fif...
# Isotrak not found
#     Range : 1470000 ... 7845026 =   2940.000 ... 15690.052 secs
# Ready.
# Reading 0 ... 6375026  =      0.000 ... 12750.052 secs...
# Opening raw data file C:\eeg\022\concatenated\022_concatenated_raw.fif...
# Isotrak not found
#     Range : 135000 ... 8055025 =    270.000 ... 16110.050 secs
# Ready.
# Reading 0 ... 7920025  =      0.000 ... 15840.050 secs...
# Opening raw data file C:\eeg\023\concatenated\023_concatenated_raw.fif...
# Isotrak not found
#     Range : 960000 ... 7770018 =   1920.000 ... 15540.036 secs
# Ready.
# Reading 0 ... 6810018  =      0.000 ... 13620.036 secs...
# Opening raw data file C:\eeg\024\concatenated\024_concatenated_raw.fif...
# Isotrak not found
#     Range : 255000 ... 7275034 =    510.000 ... 14550.068 secs
# Ready.
# Reading 0 ... 7020034  =      0.000 ... 14040.068 secs...
# Opening raw data file C:\eeg\025\concatenated\025_concatenated_raw.fif...
# Isotrak not found
#     Range : 330000 ... 7050012 =    660.000 ... 14100.024 secs
# Ready.
# Reading 0 ... 6720012  =      0.000 ... 13440.024 secs...
# Opening raw data file C:\eeg\027\concatenated\027_concatenated_raw.fif...
# Isotrak not found
#     Range : 270000 ... 9945039 =    540.000 ... 19890.078 secs
# Ready.
# Reading 0 ... 9675039  =      0.000 ... 19350.078 secs...
# Opening raw data file C:\eeg\028\concatenated\028_concatenated_raw.fif...
# Isotrak not found
#     Range : 495000 ... 8160026 =    990.000 ... 16320.052 secs
# Ready.
# Reading 0 ... 7665026  =      0.000 ... 15330.052 secs...
# Opening raw data file C:\eeg\029\concatenated\029_concatenated_raw.fif...
# Isotrak not found
#     Range : 405000 ... 6555013 =    810.000 ... 13110.026 secs
# Ready.
# Reading 0 ... 6150013  =      0.000 ... 12300.026 secs...
# Opening raw data file C:\eeg\030\concatenated\030_concatenated_raw.fif...
# Isotrak not found
#     Range : 285000 ... 8760019 =    570.000 ... 17520.038 secs
# Ready.
# Reading 0 ... 8475019  =      0.000 ... 16950.038 secs...
# Opening raw data file C:\eeg\031\concatenated\031_concatenated_raw.fif...
# Isotrak not found
#     Range : 195000 ... 7530015 =    390.000 ... 15060.030 secs
# Ready.
# Reading 0 ... 7335015  =      0.000 ... 14670.030 secs...
# Opening raw data file C:\eeg\032\concatenated\032_concatenated_raw.fif...
# Isotrak not found
#     Range : 135000 ... 9390026 =    270.000 ... 18780.052 secs
# Ready.
# Reading 0 ... 9255026  =      0.000 ... 18510.052 secs...
# Opening raw data file C:\eeg\033\concatenated\033_concatenated_raw.fif...
# Isotrak not found
#     Range : 90000 ... 7560030 =    180.000 ... 15120.060 secs
# Ready.
# Reading 0 ... 7470030  =      0.000 ... 14940.060 secs...
# Opening raw data file C:\eeg\034\concatenated\034_concatenated_raw.fif...
# Isotrak not found
#     Range : 585000 ... 8070025 =   1170.000 ... 16140.050 secs
# Ready.
# Reading 0 ... 7485025  =      0.000 ... 14970.050 secs...
# Opening raw data file C:\eeg\035\concatenated\035_concatenated_raw.fif...
# Isotrak not found
#     Range : 330000 ... 8280032 =    660.000 ... 16560.064 secs
# Ready.
# Reading 0 ... 7950032  =      0.000 ... 15900.064 secs...
# Opening raw data file C:\eeg\036\concatenated\036_concatenated_raw.fif...
# Isotrak not found
#     Range : 285000 ... 7305039 =    570.000 ... 14610.078 secs
# Ready.
# Reading 0 ... 7020039  =      0.000 ... 14040.078 secs...
# Opening raw data file C:\eeg\037\concatenated\037_concatenated_raw.fif...
# Isotrak not found
#     Range : 60000 ... 8805025 =    120.000 ... 17610.050 secs
# Ready.
# Reading 0 ... 8745025  =      0.000 ... 17490.050 secs...
# Opening raw data file C:\eeg\042\concatenated\042_concatenated_raw.fif...
# Isotrak not found
#     Range : 120000 ... 6855022 =    240.000 ... 13710.044 secs
# Ready.
# Reading 0 ... 6735022  =      0.000 ... 13470.044 secs...
# Opening raw data file C:\eeg\044\concatenated\044_concatenated_raw.fif...
# Isotrak not found
#     Range : 315000 ... 9840037 =    630.000 ... 19680.074 secs
# Ready.
# Reading 0 ... 9525037  =      0.000 ... 19050.074 secs...
# Opening raw data file C:\eeg\046\concatenated\046_concatenated_raw.fif...
# Isotrak not found
#     Range : 300000 ... 8280014 =    600.000 ... 16560.028 secs
# Ready.
# Reading 0 ... 7980014  =      0.000 ... 15960.028 secs...
# Opening raw data file C:\eeg\047\concatenated\047_concatenated_raw.fif...
# Isotrak not found
#     Range : 420000 ... 7890019 =    840.000 ... 15780.038 secs
# Ready.
# Reading 0 ... 7470019  =      0.000 ... 14940.038 secs...
# Opening raw data file C:\eeg\048\concatenated\048_concatenated_raw.fif...
# Isotrak not found
#     Range : 195000 ... 7530021 =    390.000 ... 15060.042 secs
# Ready.
# Reading 0 ... 7335021  =      0.000 ... 14670.042 secs...
# Opening raw data file C:\eeg\049\concatenated\049_concatenated_raw.fif...
# Isotrak not found
#     Range : 375000 ... 6645019 =    750.000 ... 13290.038 secs
# Ready.
# Reading 0 ... 6270019  =      0.000 ... 12540.038 secs...
# Opening raw data file C:\eeg\050\concatenated\050_concatenated_raw.fif...
# Isotrak not found
#     Range : 540000 ... 10170025 =   1080.000 ... 20340.050 secs
# Ready.
# Reading 0 ... 9630025  =      0.000 ... 19260.050 secs...
# Opening raw data file C:\eeg\051\concatenated\051_concatenated_raw.fif...
# Isotrak not found
#     Range : 510000 ... 8235019 =   1020.000 ... 16470.038 secs
# Ready.
# Reading 0 ... 7725019  =      0.000 ... 15450.038 secs...
# Opening raw data file C:\eeg\052\concatenated\052_concatenated_raw.fif...
# Isotrak not found
#     Range : 1260000 ... 9240026 =   2520.000 ... 18480.052 secs
# Ready.
# Reading 0 ... 7980026  =      0.000 ... 15960.052 secs...
# Opening raw data file C:\eeg\053\concatenated\053_concatenated_raw.fif...
# Isotrak not found
#     Range : 465000 ... 9315021 =    930.000 ... 18630.042 secs
# Ready.
# Reading 0 ... 8850021  =      0.000 ... 17700.042 secs...
# Opening raw data file C:\eeg\054\concatenated\054_concatenated_raw.fif...
# Isotrak not found
#     Range : 135000 ... 9255024 =    270.000 ... 18510.048 secs
# Ready.
# Reading 0 ... 9120024  =      0.000 ... 18240.048 secs...
# Opening raw data file C:\eeg\055\concatenated\055_concatenated_raw.fif...
# Isotrak not found
#     Range : 735000 ... 7875021 =   1470.000 ... 15750.042 secs
# Ready.
# Reading 0 ... 7140021  =      0.000 ... 14280.042 secs...
# Opening raw data file C:\eeg\056\concatenated\056_concatenated_raw.fif...
# Isotrak not found
#     Range : 420000 ... 7800023 =    840.000 ... 15600.046 secs
# Ready.
# Reading 0 ... 7380023  =      0.000 ... 14760.046 secs...
# Opening raw data file C:\eeg\057\concatenated\057_concatenated_raw.fif...
# Isotrak not found
#     Range : 195000 ... 8865028 =    390.000 ... 17730.056 secs
# Ready.
# Reading 0 ... 8670028  =      0.000 ... 17340.056 secs...
# Opening raw data file C:\eeg\058\concatenated\058_concatenated_raw.fif...
# Isotrak not found
#     Range : 465000 ... 8010015 =    930.000 ... 16020.030 secs
# Ready.
# Reading 0 ... 7545015  =      0.000 ... 15090.030 secs...
# Opening raw data file C:\eeg\059\concatenated\059_concatenated_raw.fif...
# Isotrak not found
#     Range : 4035000 ... 9870021 =   8070.000 ... 19740.042 secs
# Ready.
# Reading 0 ... 5835021  =      0.000 ... 11670.042 secs...
# Opening raw data file C:\eeg\060\concatenated\060_concatenated_raw.fif...
# Isotrak not found
#     Range : 420000 ... 8595022 =    840.000 ... 17190.044 secs
# Ready.
# Reading 0 ... 8175022  =      0.000 ... 16350.044 secs...
# Opening raw data file C:\eeg\061\concatenated\061_concatenated_raw.fif...
# Isotrak not found
#     Range : 270000 ... 7155024 =    540.000 ... 14310.048 secs
# Ready.
# Reading 0 ... 6885024  =      0.000 ... 13770.048 secs...
# Opening raw data file C:\eeg\064\concatenated\064_concatenated_raw.fif...
# Isotrak not found
#     Range : 1035000 ... 8160015 =   2070.000 ... 16320.030 secs
# Ready.
# Reading 0 ... 7125015  =      0.000 ... 14250.030 secs...
# Opening raw data file C:\eeg\066\concatenated\066_concatenated_raw.fif...
# Isotrak not found
#     Range : 450000 ... 6885017 =    900.000 ... 13770.034 secs
# Ready.
# Reading 0 ... 6435017  =      0.000 ... 12870.034 secs...
# Opening raw data file C:\eeg\067\concatenated\067_concatenated_raw.fif...
# Isotrak not found
#     Range : 825000 ... 9180031 =   1650.000 ... 18360.062 secs
# Ready.
# Reading 0 ... 8355031  =      0.000 ... 16710.062 secs...
# Opening raw data file C:\eeg\068\concatenated\068_concatenated_raw.fif...
# Isotrak not found
#     Range : 285000 ... 8625040 =    570.000 ... 17250.080 secs
# Ready.
# Reading 0 ... 8340040  =      0.000 ... 16680.080 secs...
# Opening raw data file C:\eeg\070\concatenated\070_concatenated_raw.fif...
# Isotrak not found
#     Range : 645000 ... 9390029 =   1290.000 ... 18780.058 secs
# Ready.
# Reading 0 ... 8745029  =      0.000 ... 17490.058 secs...
# Opening raw data file C:\eeg\071\concatenated\071_concatenated_raw.fif...
# Isotrak not found
#     Range : 195000 ... 9870028 =    390.000 ... 19740.056 secs
# Ready.
# Reading 0 ... 9675028  =      0.000 ... 19350.056 secs...
# Opening raw data file C:\eeg\072\concatenated\072_concatenated_raw.fif...
# Isotrak not found
#     Range : 345000 ... 8520023 =    690.000 ... 17040.046 secs
# Ready.
# Reading 0 ... 8175023  =      0.000 ... 16350.046 secs...
# Opening raw data file C:\eeg\074\concatenated\074_concatenated_raw.fif...
# Isotrak not found
#     Range : 165000 ... 6405032 =    330.000 ... 12810.064 secs
# Ready.
# Reading 0 ... 6240032  =      0.000 ... 12480.064 secs...
# Opening raw data file C:\eeg\075\concatenated\075_concatenated_raw.fif...
# Isotrak not found
#     Range : 0 ... 7950047 =      0.000 ... 15900.094 secs
# Ready.
# Reading 0 ... 7950047  =      0.000 ... 15900.094 secs...
# Opening raw data file C:\eeg\076\concatenated\076_concatenated_raw.fif...
# Isotrak not found
#     Range : 150000 ... 8415039 =    300.000 ... 16830.078 secs
# Ready.
# Reading 0 ... 8265039  =      0.000 ... 16530.078 secs...
# Opening raw data file C:\eeg\077\concatenated\077_concatenated_raw.fif...
# Isotrak not found
#     Range : 255000 ... 5610021 =    510.000 ... 11220.042 secs
# Ready.
# Reading 0 ... 5355021  =      0.000 ... 10710.042 secs...
# Opening raw data file C:\eeg\078\concatenated\078_concatenated_raw.fif...
# Isotrak not found
#     Range : 450000 ... 8550026 =    900.000 ... 17100.052 secs
# Ready.
# Reading 0 ... 8100026  =      0.000 ... 16200.052 secs...
# Opening raw data file C:\eeg\080\concatenated\080_concatenated_raw.fif...
# Isotrak not found
#     Range : 375000 ... 8280024 =    750.000 ... 16560.048 secs
# Ready.
# Reading 0 ... 7905024  =      0.000 ... 15810.048 secs...
# Opening raw data file C:\eeg\081\concatenated\081_concatenated_raw.fif...
# Isotrak not found
#     Range : 165000 ... 8970017 =    330.000 ... 17940.034 secs
# Ready.
# Reading 0 ... 8805017  =      0.000 ... 17610.034 secs...
# Opening raw data file C:\eeg\082\concatenated\082_concatenated_raw.fif...
# Isotrak not found
#     Range : 300000 ... 8130024 =    600.000 ... 16260.048 secs
# Ready.
# Reading 0 ... 7830024  =      0.000 ... 15660.048 secs...

# %% [markdown]
# ## Spindle detection

# %%
def detect_spindles_times(eeg_raw, do_filter=True, do_downsample=False, downsample_rate=100):
    
    # 1. Filter between 12 and 16 Hz
    
    data = eeg_raw.copy().pick_channels(['Fz'])

    if do_filter:
        data.filter(l_freq=12, h_freq=16)
    
    # 2. Downsample at 100 Hz (100 samples per second)

    if do_downsample:
        data.resample(downsample_rate)
    
    sfreq = data.info['sfreq']  
    channel_data = data.get_data()[0]
    # extract the filtered data
    
    
    # 3: Calculate amplitude by applying Hilbert transformation

    hilbert_signal = hilbert(channel_data)
    # apply hilbert transformation to bandpassed data
    # gives analytic signal with amplitude and phase information
    envelope = np.abs(hilbert_signal)
    # take the absolute part of the hilbert signal
    # also the instantaneous power of the signal
    # gives the envelope: amplitude modulation
    # how strength of oscillations change over time
    # size of sliding window
    
    # 4: Perform smoothing with a sliding window of 0.2 seconds
    # this removes high-frequency noise
    
    sliding_window = int(0.2 * sfreq)
    smoothed_envelope = np.convolve(envelope, np.ones(sliding_window) / sliding_window, mode='same')
    # convolving envelope with a uniform filter over the sliding window
    # convolution takes rolling average of 20 samples at a time
    # smooth the signal with the average of values in the window
    # in the smoothed envelope, can detect regions with higher amplitude 
    # which is when a spindle event occurs
    # np.ones: creates a filter kernel
    # have a filter where the sum of all elements equals 1
    # this filter is replaced by the average of the 20 surrounding samples
    # convolution between envelope and averaging filter
    # mode = 'same': so that output of convolution has same length as original envelope

    # 5. Define spindle detection threshold

    threshold = np.percentile(smoothed_envelope, 75)
    spindle_threshold = smoothed_envelope > threshold
    #threshold = np.mean(smoothed_envelope) + 1.5 * np.std(smoothed_envelope)
    #spindle_threshold = smoothed_envelope > threshold
    # threshold is 75th percentile of the smoothed envelope
    # will look at the duration later
    
    # 6. Detect spindles and define peaks and troughs for visualisation
    
    spindles = []
    # initialize list with spindles
    above_threshold = np.where(spindle_threshold)[0]
    # returns indices where signal above the threshold
    stacked_spindles = []
    # initialize list for stacking the spindles for the visualisation
    # contains aligned spindles at peak
    
    if len(above_threshold) > 0:
        # checking it's not empty
        start_idx = above_threshold[0]
        # would be the start of a potential spindle
        for i in range(1, len(above_threshold)):
            if above_threshold[i] > above_threshold[i - 1] + 1:  
                # if above threshold[1] > above_threshold[0] + 1
                # because all indices should be separated by 1
                # so here detects gaps
                # so starting from the second index
                # and comparing each index to the one before
                end_idx = above_threshold[i - 1]
                # so if above condition is true, this is the end of the spindle
                duration = (end_idx - start_idx) / sfreq
                if 0.5 <= duration <= 3:
                    # only keep spindles lasting 0.5 to 3 seconds
                    segment = channel_data[start_idx:end_idx]
                    # extract EEG segment corresponding to detected spindle
                    peak_idx = start_idx + np.argmax(segment) 
                    # extract the peak of the spindle
                    # this will be useful for later
                    spindles.append((start_idx / sfreq, end_idx / sfreq))
                    # all the spindles are stored in spindles
                    
                    # Aligning spindles at peak for visualization
                    before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
                    # still in the for loop, so this is the peak index of individual peak
                    after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
                    # extracting 1.5 seconds before and after peak
                    # max and min are used for out of bounds situations at the start and end of EEG data
                    aligned_segment = channel_data[before_peak_idx:after_peak_idx]
                    stacked_spindles.append(aligned_segment)
                    # the aligned segment is saved in stacked spindles
                
                start_idx = above_threshold[i]
                # update the start index for the for loop

        # then need to process the final spindle
        end_idx = above_threshold[-1]
        duration = (end_idx - start_idx) / sfreq
        if 0.5 <= duration <= 3:
            segment = channel_data[start_idx:end_idx]
            peak_idx = start_idx + np.argmax(segment)
            spindles.append((start_idx / sfreq, end_idx / sfreq))

            before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
            after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
            aligned_segment = channel_data[before_peak_idx:after_peak_idx]
            stacked_spindles.append(aligned_segment)
    
    return spindles
    

def detect_spindles_peaks(eeg_raw, do_filter=True, do_downsample=False, downsample_rate=100):
    
    # 1. Filter between 12 and 16 Hz
    
    data = eeg_raw.copy().pick_channels(['Fz'])

    if do_filter:
        data.filter(l_freq=12, h_freq=16)
    
    # 2. Downsample at 100 Hz (100 samples per second)
    
    if do_downsample:
        data.resample(downsample_rate)
        
    sfreq = data.info['sfreq']  
    # update to new sampling frequency
    # because used later in the code
    channel_data = data.get_data()[0]
    # extract the filtered data
    
    # 3: Calculate amplitude by applying Hilbert transformation

    hilbert_signal = hilbert(channel_data)
    # apply hilbert transformation to bandpassed data
    # gives analytic signal with amplitude and phase information
    envelope = np.abs(hilbert_signal)
    # take the absolute part of the hilbert signal
    # also the instantaneous power of the signal
    # gives the envelope: amplitude modulation
    # how strength of oscillations change over time
    # size of sliding window
    
    # 4: Perform smoothing with a sliding window of 0.2 seconds
    # this removes high-frequency noise
    
    sliding_window = int(0.2 * sfreq)
    smoothed_envelope = np.convolve(envelope, np.ones(sliding_window) / sliding_window, mode='same')
    # convolving envelope with a uniform filter over the sliding window
    # convolution takes rolling average of 20 samples at a time
    # smooth the signal with the average of values in the window
    # in the smoothed envelope, can detect regions with higher amplitude 
    # which is when a spindle event occurs
    # np.ones: creates a filter kernel
    # have a filter where the sum of all elements equals 1
    # this filter is replaced by the average of the 20 surrounding samples
    # convolution between envelope and averaging filter
    # mode = 'same': so that output of convolution has same length as original envelope

    # 5. Define spindle detection threshold

    threshold = np.percentile(smoothed_envelope, 75)
    spindle_threshold = smoothed_envelope > threshold
    # 75th percentile as criteria

    #threshold = np.mean(smoothed_envelope) + 1.5 * np.std(smoothed_envelope)
    #spindle_threshold = smoothed_envelope > threshold
    
    # 6. Detect spindles and define peaks and troughs for visualisation
    
    spindles = []
    # initialize list with spindles
    above_threshold = np.where(spindle_threshold)[0]
    # returns indices where signal above the threshold
    stacked_spindles = []
    # initialize list for stacking the spindles for the visualisation
    # contains aligned spindles at peak
    
    if len(above_threshold) > 0:
        # checking it's not empty
        start_idx = above_threshold[0]
        # would be the start of a potential spindle
        for i in range(1, len(above_threshold)):
            if above_threshold[i] > above_threshold[i - 1] + 1:  
                # if above threshold[1] > above_threshold[0] + 1
                # because all indices should be separated by 1
                # so here detects gaps
                end_idx = above_threshold[i - 1]
                # so if above condition is true, this is the end of the spindle
                duration = (end_idx - start_idx) / sfreq
                if 0.5 <= duration <= 3:
                    # only keep spindles lasting 0.5 to 3 seconds
                    segment = channel_data[start_idx:end_idx]
                    # extract EEG segment corresponding to detected spindle
                    peak_idx = start_idx + np.argmax(segment) 
                    # extract the peak of the spindle
                    # this will be useful for later
                    #spindles.append(f"Spindle detected from {start_idx / sfreq:.2f}s to {end_idx / sfreq:.2f}s, peak at {peak_idx / sfreq:.2f}s")
                    spindles.append((peak_idx / sfreq))
                    # all the spindles are stored in spindles
                    
                    # Aligning spindles at peak for visualization
                    before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
                    # still in the for loop, so this is the peak index of individual peak
                    after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
                    # extracting 1.5 seconds before and after peak
                    # max and min are used for out of bounds situations at the start and end of EEG data
                    aligned_segment = channel_data[before_peak_idx:after_peak_idx]
                    stacked_spindles.append(aligned_segment)
                    # the aligned segment is saved in stacked spindles
                
                start_idx = above_threshold[i]
                # update the start index for the for loop

        # then need to process the final spindle
        end_idx = above_threshold[-1]
        duration = (end_idx - start_idx) / sfreq
        if 0.5 <= duration <= 3:
            segment = channel_data[start_idx:end_idx]
            peak_idx = start_idx + np.argmax(segment)
            spindles.append((peak_idx / sfreq))

            before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
            after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
            aligned_segment = channel_data[before_peak_idx:after_peak_idx]
            stacked_spindles.append(aligned_segment)

    
    return spindles

def detect_spindles_peaks_average(eeg_raw, do_filter=True, do_downsample=False, downsample_rate=100):
    # same as above but returns spindles and stacked spindles
    
    # 1. Filter between 12 and 16 Hz
    
    data = eeg_raw.copy().pick_channels(['Fz'])

    if do_filter:
        data.filter(l_freq=12, h_freq=16)
    
    # 2. Downsample at 100 Hz (100 samples per second)
    
    if do_downsample:
        data.resample(downsample_rate)
        
    sfreq = data.info['sfreq']  
    # update to new sampling frequency
    # because used later in the code
    channel_data = data.get_data()[0]
    # extract the filtered data
    
    # 3: Calculate amplitude by applying Hilbert transformation

    hilbert_signal = hilbert(channel_data)
    # apply hilbert transformation to bandpassed data
    # gives analytic signal with amplitude and phase information
    envelope = np.abs(hilbert_signal)
    # take the absolute part of the hilbert signal
    # also the instantaneous power of the signal
    # gives the envelope: amplitude modulation
    # how strength of oscillations change over time
    # size of sliding window
    
    # 4: Perform smoothing with a sliding window of 0.2 seconds
    # this removes high-frequency noise
    
    sliding_window = int(0.2 * sfreq)
    smoothed_envelope = np.convolve(envelope, np.ones(sliding_window) / sliding_window, mode='same')
    # convolving envelope with a uniform filter over the sliding window
    # convolution takes rolling average of 20 samples at a time
    # smooth the signal with the average of values in the window
    # in the smoothed envelope, can detect regions with higher amplitude 
    # which is when a spindle event occurs
    # np.ones: creates a filter kernel
    # have a filter where the sum of all elements equals 1
    # this filter is replaced by the average of the 20 surrounding samples
    # convolution between envelope and averaging filter
    # mode = 'same': so that output of convolution has same length as original envelope

    # 5. Define spindle detection threshold

    threshold = np.percentile(smoothed_envelope, 75)
    spindle_threshold = smoothed_envelope > threshold
    # 75th percentile as criteria

    #threshold = np.mean(smoothed_envelope) + 1.5 * np.std(smoothed_envelope)
    #spindle_threshold = smoothed_envelope > threshold
    
    # 6. Detect spindles and define peaks and troughs for visualisation
    
    spindles = []
    # initialize list with spindles
    above_threshold = np.where(spindle_threshold)[0]
    # returns indices where signal above the threshold
    stacked_spindles = []
    # initialize list for stacking the spindles for the visualisation
    # contains aligned spindles at peak
    
    if len(above_threshold) > 0:
        # checking it's not empty
        start_idx = above_threshold[0]
        # would be the start of a potential spindle
        for i in range(1, len(above_threshold)):
            if above_threshold[i] > above_threshold[i - 1] + 1:  
                # if above threshold[1] > above_threshold[0] + 1
                # because all indices should be separated by 1
                # so here detects gaps
                end_idx = above_threshold[i - 1]
                # so if above condition is true, this is the end of the spindle
                duration = (end_idx - start_idx) / sfreq
                if 0.5 <= duration <= 3:
                    # only keep spindles lasting 0.5 to 3 seconds
                    segment = channel_data[start_idx:end_idx]
                    # extract EEG segment corresponding to detected spindle
                    peak_idx = start_idx + np.argmax(segment) 
                    # extract the peak of the spindle
                    # this will be useful for later
                    #spindles.append(f"Spindle detected from {start_idx / sfreq:.2f}s to {end_idx / sfreq:.2f}s, peak at {peak_idx / sfreq:.2f}s")
                    spindles.append((peak_idx / sfreq))
                    # all the spindles are stored in spindles
                    
                    # Aligning spindles at peak for visualization
                    before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
                    # still in the for loop, so this is the peak index of individual peak
                    after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
                    # extracting 1.5 seconds before and after peak
                    # max and min are used for out of bounds situations at the start and end of EEG data
                    aligned_segment = channel_data[before_peak_idx:after_peak_idx]
                    stacked_spindles.append(aligned_segment)
                    # the aligned segment is saved in stacked spindles
                
                start_idx = above_threshold[i]
                # update the start index for the for loop

        # then need to process the final spindle
        end_idx = above_threshold[-1]
        duration = (end_idx - start_idx) / sfreq
        if 0.5 <= duration <= 3:
            segment = channel_data[start_idx:end_idx]
            peak_idx = start_idx + np.argmax(segment)
            spindles.append((peak_idx / sfreq))

            before_peak_idx = max(0, peak_idx - int(1.5 * sfreq))
            after_peak_idx = min(len(channel_data), peak_idx + int(1.5 * sfreq))
            aligned_segment = channel_data[before_peak_idx:after_peak_idx]
            stacked_spindles.append(aligned_segment)

    
    return spindles, stacked_spindles

# %%
def visualize_spindles(stacked_spindles, plot_name):
    max_len = max(len(seg) for seg in stacked_spindles)
    padded_stacked_spindles = [np.pad(seg, (0, max_len - len(seg)), constant_values=np.nan) for seg in stacked_spindles]
    avg_spindle_waveform = np.nanmean(padded_stacked_spindles, axis=0)
    time_axis = np.linspace(-1.5, 1.5, len(avg_spindle_waveform))
    # already stacking 1.5 around each side so keep this

    plt.figure(figsize=(8, 4))
    plt.plot(time_axis, avg_spindle_waveform, color="blue", label="Mean Spindle")
    plt.axvline(0, color="red", linestyle="--", label="Peak (0s)")
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude (µV)')
    plt.title(plot_name)
    plt.legend()
    plt.show()

# %% [markdown]
# ## Slow oscillation detection

# %%
def detect_slow_oscillations_times(combined_raw, do_filter=True, do_downsample=False, downsample_rate=100):

    # according to methods from Klinzing et al.(2016)

    data = combined_raw.copy().pick_channels(['Fz'])

    if do_filter:
        data.filter(l_freq=0.16, h_freq=1.25)

    if do_downsample:
        data.resample(downsample_rate)
        
    sfreq = data.info['sfreq']
    channel_data = data.get_data()[0]
    
    # 3. find all positive-to-negative zero-crossings
    
    # zero_crossings = np.where( S!= 0)[0]
    # can also save this somewhere for further detection of spindles
    
    S = np.diff(np.sign(channel_data))
    # np.sign returns an array with 1 (positive), 0 (zero), -1 (negative)
    # np.diff calculates the difference between consecutive elements in an array
    # positive value: transition from negative to positive
    # negative value: transition from positive to negative
    # when it's a zero, means that value stayed the same
    zero_crossings = np.where(S < 0)[0]
    # -2 is when a positive-to-negative zero-crossing occurs
    # goes from 1 to -1 
    # -1 - 1 = -2
    # [0] extracts the actual array
    # extracts the indices of interest from current_data (not S)
    #signs = np.sign(current_data)
    #pos_to_neg = np.where((signs[:-1] > 0) & (signs[1:] < 0))[0]
    # detect +1 to -1
    #neg_to_pos = np.where((signs[:-1] <  0) & (signs[1:] > 0))[0]
    # detect -1 to +1

    # 4. Detect peak potentials in each pair
    slow_oscillations = []
    negative_peaks = []
    positive_peaks = []
    peak_to_peak_amplitudes = []
    candidate_indices = []

    # for loop for each pair
    # to collect all the negative and positive peaks
    # to further apply criteria
    count = 0
    for i in range(0, len(zero_crossings)-1, 1):
        # loop through all the zero_crossings
        # step of 1 (with step of 2, miss some zero_crossings)
        start_idx = zero_crossings[i] + 1
        # assigns index of zero-crossing (representing start of potential SO)
        # to start_idx
        end_idx = zero_crossings[i + 1] + 1
        # assigns index of next zero-crossing (representing end of potential SO)
        # to end_idx

        # find the negative to positive crossing in between
        #mid_crossings = neg_to_pos[(neg_to_pos > start_idx) & (neg_to_pos < end_idx)]

        #if len(mid_crossings) != 1:
            #continue

        #mid_idx = mid_crossings [0]

        #duration = (end_idx - start_idx) / sfreq
        #if not (0.8 <= duration <= 2.0):
  
        
        segment_length = (end_idx - start_idx) / sfreq

        # need to add +1 because of way extract segment later

        # have identified index for the pair
        
        # extract data segment between crossings
        
        # find peaks
        if 0.8 <= segment_length <= 2.0:
            count += 1
            segment = channel_data[start_idx:end_idx]
            positive_peak = np.max(segment)
            negative_peak = np.min(segment)
            peak_to_peak_amplitude = positive_peak - negative_peak

        # store values
            candidate_indices.append((start_idx, end_idx))
            positive_peaks.append(positive_peak)
            negative_peaks.append(negative_peak)
            peak_to_peak_amplitudes.append(peak_to_peak_amplitude)

    # calculate mean values for comparison
    #mean_negative_peak = np.mean(negative_peaks)
    # mean_negative_peak = np.mean(negative_peaks) if negative_peaks else 0
    #mean_peak_to_peak_amplitude = np.mean(peak_to_peak_amplitudes)
    # mean_peak_to_peak_amplitude = np.mean(peak_to_peak_amplitudes) if peak_to_peak_amplitudes else 0

    negative_peak_threshold = np.percentile(negative_peaks, 25)
    # keep lowest negative peaks (under the 25th percentile)
    peak_to_peak_amplitude_threshold = np.percentile(peak_to_peak_amplitudes, 75)
    # keep largest peak-to-peak amplitude (over 75th percentile)

    for (start_idx, end_idx), negative_peak, peak_to_peak_amplitude in zip(candidate_indices, negative_peaks, peak_to_peak_amplitudes):
        if peak_to_peak_amplitude >= peak_to_peak_amplitude_threshold and negative_peak <= negative_peak_threshold:
            slow_oscillations.append((start_idx / sfreq, end_idx / sfreq))
            
    return slow_oscillations
    # returns a list of tuples, in which each tuple represents the start and end times of
    # a detected slow oscillation

def detect_slow_oscillations_peaks(combined_raw, do_filter=True, do_downsample=True, downsample_rate=100):

    # according to methods from Klinzing et al.(2016)

    data = combined_raw.copy().pick_channels(['Fz'])

    if do_filter:
        data.filter(l_freq=0.16, h_freq=1.25)

    if do_downsample:
        data.resample(downsample_rate)
        
    sfreq = data.info['sfreq']
    channel_data = data.get_data()[0]
    
    # 3. find all positive-to-negative zero-crossings
    
    # zero_crossings = np.where( S!= 0)[0]
    # can also save this somewhere for further detection of spindles
    
    S = np.diff(np.sign(channel_data))
    # np.sign returns an array with 1 (positive), 0 (zero), -1 (negative)
    # np.diff calculates the difference between consecutive elements in an array
    # positive value: transition from negative to positive
    # negative value: transition from positive to negative
    # when it's a zero, means that value stayed the same
    zero_crossings = np.where(S < 0)[0]
    # -2 is when a positive-to-negative zero-crossing occurs
    # goes from 1 to -1 
    # -1 - 1 = -2
    # [0] extracts the actual array
    # extracts the indices of interest from current_data (not S)


    # 4. Detect peak potentials in each pair
    slow_oscillations = []
    slow_oscillations_peaks = []
    negative_peaks = []
    positive_peaks = []
    peak_to_peak_amplitudes = []
    candidate_indices =  []

    # for loop for each pair
    # to collect all the negative and positive peaks
    # to further apply criteria
    count = 0
    for i in range(0, len(zero_crossings) - 1, 1):
        # loop through all the zero_crossings
        # step of 1 (with step of 2, miss some zero_crossings)
        start_idx = zero_crossings[i] + 1
        # assigns index of zero-crossing (representing start of potential SO)
        # to start_idx
        end_idx = zero_crossings[i + 1] + 1
        # assigns index of next zero-crossing (representing end of potential SO)
        # to end_idx
        segment_length = (end_idx - start_idx) / sfreq

        # need to add +1 because of way extract segment later

        # have identified index for the pair
        
        # extract data segment between crossings
        
        # find peaks
        if 0.8 <= segment_length <= 2.0:
            count += 1
            segment = channel_data[start_idx:end_idx]
            positive_peak = np.max(segment)
            negative_peak = np.min(segment)
            peak_to_peak_amplitude = positive_peak - negative_peak

        # store values
            candidate_indices.append((start_idx, end_idx))
            positive_peaks.append(positive_peak)
            negative_peaks.append(negative_peak)
            peak_to_peak_amplitudes.append(peak_to_peak_amplitude)

    # calculate mean values for comparison
    #mean_negative_peak = np.mean(negative_peaks)
    # mean_negative_peak = np.mean(negative_peaks) if negative_peaks else 0
    #mean_peak_to_peak_amplitude = np.mean(peak_to_peak_amplitudes)
    # mean_peak_to_peak_amplitude = np.mean(peak_to_peak_amplitudes) if peak_to_peak_amplitudes else 0

    negative_peak_threshold = np.percentile(negative_peaks, 25)
    peak_to_peak_amplitude_threshold = np.percentile(peak_to_peak_amplitudes, 75)

    for (start_idx, end_idx), negative_peak, peak_to_peak_amplitude in zip(candidate_indices, negative_peaks, peak_to_peak_amplitudes):
        if peak_to_peak_amplitude >= peak_to_peak_amplitude_threshold and negative_peak <= negative_peak_threshold:
            slow_oscillations.append((start_idx / sfreq, end_idx / sfreq))
            slow_oscillations_peaks.append((negative_peak, positive_peak))

            
    return slow_oscillations_peaks
    # returns a list of tuples, in which each tuple represents the start and end times of
    # a detected slow oscillation

# %%
# now want to visualise slow oscillations
# find peak and trough for each of them, and then stack them all together to visualise

# this function aligns detected slow oscillations at their trough
# creates an average SO waveform

def visualize_and_stack_slow_oscillations_trough(combined_raw, slow_oscillations, plot_name):

    # Apply band-pass filter between 0.3 and 1.25 Hz
    filtered_data = combined_raw.copy().filter(l_freq=0.16, h_freq=1.25)
    # downsampling to 100 Hz
    #filtered_data.resample(100)
    filtered_channel_data = filtered_data.get_data(picks="Fz")[0]
    
    sfreq = filtered_data.info['sfreq']
    
    stacked_data = []
    # loop through each slow oscillation
    for start_time, end_time in slow_oscillations:
        # to convert start and end times to sample indices
        start_idx = int(start_time * sfreq)
        end_idx = int(end_time * sfreq)

        # extract the slow oscillation segment
        segment = filtered_channel_data[start_idx:end_idx]

        global_trough_idx = np.argmin(filtered_channel_data[start_idx:end_idx]) + start_idx
         # argmin finds the index of the min value
        # min finds the min value itself
        
        # calculate indices for 1.5 seconds before and after trough
        before_trough_idx = max(0, global_trough_idx - int(1.5 * sfreq))
        # substracts 1.5 seconds from the trough index
        # max as a safety check, to make sure that before_trough_index never negative
        # to prevent accessing data points before the beginning of the segment
        after_trough_idx = min(len(filtered_channel_data), global_trough_idx + int(1.5 * sfreq))
        # adds 1.5 seconds to the trough index
        # min is another safety check
        
        # extract the segment around the trough
        aligned_segment = filtered_channel_data[before_trough_idx:after_trough_idx]

        # append the aligned segment to the stacked data
        stacked_data.append(aligned_segment)

    # Find the maximum length of the segments
    max_len = max(len(segment) for segment in stacked_data)

    # Pad shorter segments with np.nan
    padded_stacked_data = []
    for segment in stacked_data:
        pad_len = max_len - len(segment)
        # how much padding is needed
        pad_before = pad_len // 2
        pad_after = pad_len - pad_before
        padded_segment = np.pad(segment, (pad_before, pad_after), 'constant', constant_values=np.nan)
        # distribute the padding before and after the segment
        # use NaNs instead of zeros to avoid bias
        padded_stacked_data.append(padded_segment)

    # calculate the average stacked slow oscillation
    average_padded_stacked_data = np.nanmean(padded_stacked_data, axis=0)
    # compute average waveform by ignoring NaNs

    # visualize the average stacked slow oscillation
    time_axis = np.linspace(-1.5, 1.5, len(average_padded_stacked_data))
    # this is to create the time axis
    plt.figure(figsize=(8,4))
    plt.plot(time_axis, average_padded_stacked_data, color="blue", label="Mean SO")
    plt.axvline(0, color="red", linestyle="--", label="Trough (0s)")
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude (µV)')
    plt.title(plot_name)
    plt.legend()
    plt.show()

# %% [markdown]
# ## SO-spindle coupling detection

# %%
def detect_slow_oscillations_spindles_coupling_so_times(combined_raw, do_filter=True, do_downsample=True, downsample_rate=100):
    slow_oscillations_peaks = detect_slow_oscillations_peaks(combined_raw, do_filter=do_filter, do_downsample=do_downsample, downsample_rate=downsample_rate)
    slow_oscillations_times = detect_slow_oscillations_times(combined_raw, do_filter=do_filter, do_downsample=do_downsample, downsample_rate=downsample_rate)
    spindles_peaks = detect_spindles_peaks(combined_raw, do_filter=do_filter, do_downsample=do_downsample, downsample_rate=downsample_rate)

    coupling_times = []
    coupling_times_so = []

    # first detect the coupling events
    for start_time, end_time in slow_oscillations_times:
    #for start_time, end_time (negative_peak, positive_peak) in zip(slow_oscillations_times, slow_oscillations_peaks):
        for peak in spindles_peaks:
            if start_time < peak < end_time:
                # if negative_peak < peak < end_time:
                coupling_times.append(peak)
                # if the peak of the spindle is between the negative and positive trough
                # add it to list of coupling times

    # then calculate the slow oscillation length
    for start_time, end_time in slow_oscillations_times:
        current_start_time = start_time
        current_end_time = end_time
        for coupling_peak in coupling_times:
            if current_start_time < coupling_peak < current_end_time:
                coupling_times_so.append((current_start_time, current_end_time))

    return coupling_times_so

# %% [markdown]
# ## Detection

# %% [markdown]
# ### at 500 Hz

# %% [markdown]
# ## Visualisations

# %% [markdown]
# ### Spindle

# %%
all_avg_spindles = []

# since takes too much memory to do on all the concatenated data at once
# do the analysis per participant and average
for pid in participant_ids:
    raw = combined_raw_data[pid]
    spindles, stacked = detect_spindles_peaks_average(raw, do_downsample=True)
    # downsample to save some memory
    
    # same code as in function
    max_len = max(len(seg) for seg in stacked) if stacked else 0
    if max_len > 0:
        padded_stacked_spindles = [np.pad(seg, (0, max_len - len(seg)), constant_values=np.nan) for seg in stacked]
        avg_spindle_waveform = np.nanmean(padded_stacked_spindles, axis=0)
        all_avg_spindles.append(avg_spindle_waveform)

    # trick: clear the raw data to save the memory
    del spindles
    del stacked

# final average plot
if all_avg_spindles:
    max_len_all = max(len(avg) for avg in all_avg_spindles)
    padded_all_avg_spindles = [np.pad(avg, (0, max_len_all - len(avg)), constant_values=np.nan) for avg in all_avg_spindles]
    final_avg_spindle = np.nanmean(padded_all_avg_spindles, axis=0)
    
    time_axis = np.linspace(-1.5, 1.5, len(final_avg_spindle))

    plt.figure(figsize=(8, 4))
    plt.plot(time_axis, final_avg_spindle, color="blue", label="Mean Spindle")
    plt.axvline(0, color="red", linestyle="--", label="Peak (0s)")
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude (µV)')
    plt.title("Average Spindle for 53 Participants")
    plt.legend()
    plt.show()
else:
    print("No spindles detected for any participant.")
     # if no spindles detected
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 38 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 15 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 29 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 32 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 41 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 30 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 29 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 48 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)

# %% [markdown]
# ### Slow oscillation

# %%
slow_oscillations_times = detect_slow_oscillations_times(large_participants_raw, do_filter=True, do_downsample=False)
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1353 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)

# %%
## if do_downsample=True, need to turn on downsampling in visualisation function

# this is the only function that does not throw a memory error
# have done this in a separate notebook

visualize_and_stack_slow_oscillations_trough(
    large_participants_raw,
    slow_oscillations_times,
    plot_name="Average Slow Oscillation for 53 participants"
)
# Out:
# Filtering raw data in 1353 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)

# %% [markdown]
# ## Coupling visualisation

# %%
def visualize_so_spindle_coupling(raw, so_spindle_coupling_times, plot_name, do_downsample=False):
    # here compute the STFT for spindles
    # not all the data
    # did apply per-frequency z score normalisation

    # slow oscillation 
    so_filtered_data = raw.copy().filter(l_freq=0.16, h_freq=1.25)
    if do_downsample:
        so_filtered_data.resample(100)
    so_channel_data = so_filtered_data.get_data(picks="Fz")[0]
    sfreq = so_filtered_data.info['sfreq']
    # define the sampling frequency
    # after or before downsampling

    # spindle
    spindle_filtered_data = raw.copy().filter(l_freq=12, h_freq=16)
    if do_downsample:
        spindle_filtered_data.resample(100)
    spindle_channel_data = spindle_filtered_data.get_data(picks="Fz")[0]

    # raw
    raw_channel_data = raw.get_data(picks="Fz")[0]


    # align everything to the SO trough
    aligned_so_segments = []
    aligned_spindle_segments = []
    aligned_raw_segments = []
    for start_time, end_time in so_spindle_coupling_times:
        # extract start and end times of SOs
        # do this for every coupled SO
        start_idx = int(start_time * sfreq)
        end_idx = int(end_time * sfreq)

        # trough is argmin
        so_segment = so_channel_data[start_idx:end_idx]
        trough_idx = np.argmin(so_segment) + start_idx

        # keep -1.5 and 1.5 seconds around the trough
        before_trough_idx = max(0, trough_idx - int(1.5 * sfreq))
        after_trough_idx = min(len(so_channel_data), trough_idx + int(1.5 * sfreq))
        aligned_so_segment = so_channel_data[before_trough_idx:after_trough_idx]
        aligned_so_segments.append(aligned_so_segment)

        # extract spindle data
        aligned_spindle_segment = spindle_channel_data[before_trough_idx:after_trough_idx]
        # extract the data between 12 and 16 Hz that occurs during that same time window
        aligned_spindle_segments.append(aligned_spindle_segment)


    # pad and average the SO (as in previous function)
    max_len_so = max(len(seg) for seg in aligned_so_segments)
    padded_so_segments = [np.pad(seg, (0, max_len_so - len(seg)), constant_values=np.nan) for seg in aligned_so_segments]
    avg_so_waveform = np.nanmean(padded_so_segments, axis=0)
    time_axis = np.linspace(-1.5, 1.5, len(avg_so_waveform))

    # average spectrogram for spindle and pad
    max_len_spindle = max(len(seg) for seg in aligned_spindle_segments)
    padded_spindle_segments = [np.pad(seg, (0, max_len_spindle- len(seg)), constant_values=np.nan) for seg in aligned_spindle_segments]

    # STFT for spindle
    baseline = np.mean(spindle_channel_data[:50])
    # first 50 time points of data
    Sxx_list = []
    for seg in padded_spindle_segments:
        # NaNs are replaced with 0
        if np.isnan(seg).any():
            seg = np.nan_to_num(seg) 
        # baseline correction
        seg = seg - baseline
        freqs, times, Sxx = signal.stft(seg, fs=sfreq, nperseg=int(sfreq/4), noverlap=int(sfreq/8))
        # z-score normalisation
        m = np.mean(Sxx)
        s = np.std(Sxx)
        Sxx = (Sxx - m) / s
        Sxx_list.append(np.abs(Sxx))

    # then average all the spectrograms
    avg_Sxx = np.nanmean(Sxx_list, axis=0)

    # interpolation (cubic)
    #tim_interp = np.linspace(times.min(), times.max(), 5120)
    #freq_interp = np.linspace(freqs.min(), freqs.max(), 1024)
    #interp_tf = RegularGridInterpolator(times, freqs, avg_Sxx, kind='cubic')
    #pow_interp_tf = interp_tf(tim_interp, freq_interp)

    # interpolation (cubic)
    tim_interp = np.linspace(times.min(), times.max(), 5120) 
    freq_interp = np.linspace(freqs.min(), freqs.max(), 1024)
    grid = (freqs, times) 
    points = np.array(np.meshgrid(freq_interp, tim_interp, indexing='ij')).reshape(2, -1).T
    pow_interp_tf = interpn(grid, avg_Sxx, points, method='cubic')
    pow_interp_tf = pow_interp_tf.reshape(len(freq_interp), len(tim_interp))

    # plot
    fig, ax = plt.subplots(figsize=(10, 6))

    # plot spectrogram
    #im = ax.pcolormesh(times - 1.5, freqs, avg_Sxx, shading='gouraud', cmap='viridis')
    im = ax.imshow(pow_interp_tf, aspect='auto', extent=[times.min()-1.5, times.max()-1.5, freqs.min(), freqs.max()], origin='lower', cmap='viridis', vmin=0, vmax=8)
    fig.colorbar(im, ax=ax, label='Power/Frequency (dB/Hz)', pad=0.02)
    #cbar = fig.colorbar(im, ax=ax, label='Power/Frequency (dB/Hz)', pad=0.1)
    #cbar.set_label('Z-scored Power', rotation=270, labelpad=15)
    

    # Overlay SO waveform
    ax2 = ax.twinx()
    ax2.plot(time_axis, avg_so_waveform, color='red', linewidth=2, label='Average SO')
    ax2.set_ylabel('Amplitude (µV)', color='red')
    ax2.tick_params(axis='y', labelcolor='red')
    ax2.axvline(0, color='white', linestyle='--', label="Trough (0s)")


    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Frequency (Hz)')
    ax.set_ylim(0, 30)
    ax.set_title(plot_name)
    ax.legend()
    #ax.legend(loc='upper left')
    #ax2.legend(loc='upper right')
    plt.show()

def visualize_so_no_spindle_coupling(raw, slow_oscillations_times, spindles_peaks, plot_name, do_downsample=False):

    # identify non-coupled SOs
    # as those that don't respect the definition
    non_coupled_so_times = []
    for start_time, end_time in slow_oscillations_times:
        coupled = False
        for peak in spindles_peaks:
            if start_time < peak < end_time:
                coupled = True
                break
        if not coupled:
            non_coupled_so_times.append((start_time, end_time))

    # slow oscillation
    so_filtered_data = raw.copy().filter(l_freq=0.16, h_freq=1.25)
    if do_downsample:
        so_filtered_data.resample(100)
    so_channel_data = so_filtered_data.get_data(picks="Fz")[0]
    sfreq = so_filtered_data.info['sfreq']

    # spindle
    spindle_filtered_data = raw.copy().filter(l_freq=12, h_freq=16)
    if do_downsample:
        spindle_filtered_data.resample(100)
    spindle_channel_data = spindle_filtered_data.get_data(picks="Fz")[0]

    # raw
    raw_channel_data = raw.get_data(picks="Fz")[0]

    # align everything to the SO trough
    aligned_so_segments = []
    aligned_spindle_segments = []
    for start_time, end_time in non_coupled_so_times:
        start_idx = int(start_time * sfreq)
        end_idx = int(end_time * sfreq)

        # trough is argming
        so_segment = so_channel_data[start_idx:end_idx]
        trough_idx = np.argmin(so_segment) + start_idx

        # same logic as above
        before_trough_idx = max(0, trough_idx - int(1.5 * sfreq))
        after_trough_idx = min(len(so_channel_data), trough_idx + int(1.5 * sfreq))
        aligned_so_segment = so_channel_data[before_trough_idx:after_trough_idx]
        aligned_so_segments.append(aligned_so_segment)

        # spindle aligned to SO trough
        aligned_spindle_segment = spindle_channel_data[before_trough_idx:after_trough_idx]
        aligned_spindle_segments.append(aligned_spindle_segment)


    # SO average
    max_len_so = max(len(seg) for seg in aligned_so_segments)
    padded_so_segments = [np.pad(seg, (0, max_len_so - len(seg)), constant_values=np.nan) for seg in aligned_so_segments]
    avg_so_waveform = np.nanmean(padded_so_segments, axis=0)
    time_axis = np.linspace(-1.5, 1.5, len(avg_so_waveform))

    # spindle spectogram average and pad
    max_len_spindle = max(len(seg) for seg in aligned_spindle_segments)
    padded_spindle_segments = [np.pad(seg, (0, max_len_spindle- len(seg)), constant_values=np.nan) for seg in aligned_spindle_segments]

    # STFT for spindles
    Sxx_list = []
    baseline = np.mean(spindle_channel_data[:50])
    for seg in padded_spindle_segments:
        # Handle potential NaNs from padding
        if np.isnan(seg).any():
            seg = np.nan_to_num(seg) # Replace NaNs with 0 for STFT
        seg = seg - baseline
        freqs, times, Sxx = signal.stft(seg, fs=sfreq, nperseg=int(sfreq/4), noverlap=int(sfreq/8))
        # z-score normalisation
        m = np.mean(Sxx)
        s = np.std(Sxx)
        Sxx = (Sxx - m) / s
        Sxx_list.append(np.abs(Sxx))

    # spectrogram average
    avg_Sxx = np.nanmean(Sxx_list, axis=0)

    # interpolation (cubic)
    tim_interp = np.linspace(times.min(), times.max(), 5120) 
    freq_interp = np.linspace(freqs.min(), freqs.max(), 1024)
    grid = (freqs, times) 
    points = np.array(np.meshgrid(freq_interp, tim_interp, indexing='ij')).reshape(2, -1).T
    pow_interp_tf = interpn(grid, avg_Sxx, points, method='cubic')
    pow_interp_tf = pow_interp_tf.reshape(len(freq_interp), len(tim_interp))


    # plot
    fig, ax = plt.subplots(figsize=(10, 6))

    # spectogram plot
    #im = ax.pcolormesh(times - 1.5, freqs, avg_Sxx, shading='gouraud', cmap='viridis')
    im = ax.imshow(pow_interp_tf, aspect='auto', extent=[times.min()-1.5, times.max()-1.5, freqs.min(), freqs.max()], origin='lower', cmap='viridis', vmin=0, vmax=8)
    fig.colorbar(im, ax=ax, label='Power/Frequency (dB/Hz)', pad=0.02)
    #cbar = fig.colorbar(im, ax=ax, label='Power/Frequency (dB/Hz)', pad=0.1)
    #cbar.set_label('Z-scored Power', rotation=270, labelpad=15)

    # SO waveform
    ax2 = ax.twinx()
    ax2.plot(time_axis, avg_so_waveform, color='red', linewidth=2, label='Average SO')
    ax2.set_ylabel('Amplitude (µV)', color='red')
    ax2.tick_params(axis='y', labelcolor='red')
    ax2.set_ylim(-130, 40)
    ax2.axvline(0, color='white', linestyle='--', label="Trough (0s)")


    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Frequency (Hz)')
    ax.set_ylim(0, 30)
    ax.set_title(plot_name)
    ax.legend()
    #ax.legend(loc='upper left')
    #ax2.legend(loc='upper right')
    plt.show()

# %%
spindles_peaks = detect_spindles_peaks(
    large_participants_raw,
    do_filter=True,
    do_downsample=False
)

visualize_so_spindle_coupling(
    large_participants_raw,
    so_spindle_coupling_times,
    "Average Coupled SO waveform overlaid on Spindle STFT representation for 53 participants",
    do_downsample=False
)

visualize_so_no_spindle_coupling(
    large_participants_raw,
    slow_oscillations_times,
    spindles_peaks,
    "Average Coupled SO waveform overlaid on Spindle STFT representation for 53 participants",
    do_downsample=False
)
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1353 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 spindles_peaks = detect_spindles_peaks(
#       2     large_participants_raw,
#       3     do_filter=True,
#       4     do_downsample=False
#       5 )
#       7 visualize_so_spindle_coupling(
#       8     large_participants_raw,
#       9     so_spindle_coupling_times,
#      10     "Average Coupled SO waveform overlaid on Spindle STFT representation for 53 participants",
#      11     do_downsample=False
#      12 )
#      14 visualize_so_no_spindle_coupling(
#      15     large_participants_raw,
#      16     slow_oscillations_times,
#    (...)
#      19     do_downsample=False
#      20 )
#
# Cell In[4], line 142, in detect_spindles_peaks(eeg_raw, do_filter, do_downsample, downsample_rate)
#     137 channel_data = data.get_data()[0]
#     138 # extract the filtered data
#     139
#     140 # 3: Calculate amplitude by applying Hilbert transformation
# --> 142 hilbert_signal = hilbert(channel_data)
#     143 # apply hilbert transformation to bandpassed data
#     144 # gives analytic signal with amplitude and phase information
#     145 envelope = np.abs(hilbert_signal)
#
# File ~\anaconda3\envs\msc_research_project\Lib\site-packages\scipy\signal\_signaltools.py:2419, in hilbert(x, N, axis)
#    2416 if N <= 0:
#    2417     raise ValueError("N must be positive.")
# -> 2419 Xf = sp_fft.fft(x, N, axis=axis)
#    2420 h = np.zeros(N, dtype=Xf.dtype)
#    2421 if N % 2 == 0:
#
# File ~\anaconda3\envs\msc_research_project\Lib\site-packages\scipy\fft\_backend.py:28, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      26 if fn is None:
#      27     return NotImplemented
# ---> 28 return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\msc_research_project\Lib\site-packages\scipy\fft\_basic_backend.py:79, in fft(x, n, axis, norm, overwrite_x, workers, plan)
#      77 def fft(x, n=None, axis=-1, norm=None,
#      78         overwrite_x=False, workers=None, *, plan=None):
# ---> 79     return _execute_1D('fft', _pocketfft.fft, x, n=n, axis=axis, norm=norm,
#      80                        overwrite_x=overwrite_x, workers=workers, plan=plan)
#
# File ~\anaconda3\envs\msc_research_project\Lib\site-packages\scipy\fft\_basic_backend.py:32, in _execute_1D(func_str, pocketfft_func, x, n, axis, norm, overwrite_x, workers, plan)
#      30 if is_numpy(xp):
#      31     x = np.asarray(x)
# ---> 32     return pocketfft_func(x, n=n, axis=axis, norm=norm,
#      33                           overwrite_x=overwrite_x, workers=workers, plan=plan)
#      35 norm = _validate_fft_args(workers, plan, norm)
#      36 if hasattr(xp, 'fft'):
#
# File ~\anaconda3\envs\msc_research_project\Lib\site-packages\scipy\fft\_pocketfft\basic.py:31, in c2c(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      27     raise ValueError(message)
#      29 out = (tmp if overwrite_x and tmp.dtype.kind == 'c' else None)
# ---> 31 return pfft.c2c(tmp, (axis,), forward, norm, out, workers)
#
# MemoryError: std::bad_alloc

# %%
# visualize_so_spindle coupling

# downsampling everything to 100 Hz to speed it up
all_aligned_so_segments = []
all_aligned_spindle_segments = []

for pid in participant_ids:
    raw = combined_raw_data[pid]
    so_spindle_coupling_times = detect_slow_oscillations_spindles_coupling_so_times(raw, do_downsample=True)

    # this is the code that comes from the visualize function
    # but doing this per participant now
    so_filtered_data = raw.copy().filter(l_freq=0.16, h_freq=1.25)
    so_filtered_data.resample(100)
    so_channel_data = so_filtered_data.get_data(picks="Fz")[0]
    sfreq = so_filtered_data.info['sfreq']

    spindle_filtered_data = raw.copy().filter(l_freq=12, h_freq=16)
    spindle_filtered_data.resample(100)
    spindle_channel_data = spindle_filtered_data.get_data(picks="Fz")[0]

    for start_time, end_time in so_spindle_coupling_times:
        start_idx = int(start_time * sfreq)
        end_idx = int(end_time * sfreq)
        so_segment = so_channel_data[start_idx:end_idx]
        trough_idx = np.argmin(so_segment) + start_idx
        
        before_trough_idx = max(0, trough_idx - int(1.5 * sfreq))
        after_trough_idx = min(len(so_channel_data), trough_idx + int(1.5 * sfreq))
        
        aligned_so_segment = so_channel_data[before_trough_idx:after_trough_idx]
        all_aligned_so_segments.append(aligned_so_segment)

        aligned_spindle_segment = spindle_channel_data[before_trough_idx:after_trough_idx]
        all_aligned_spindle_segments.append(aligned_spindle_segment)
    
    del raw
    del so_spindle_coupling_times
    del so_filtered_data
    del spindle_filtered_data

# for average plot
if all_aligned_so_segments:
    # pad and average SO
    max_len_so = max(len(seg) for seg in all_aligned_so_segments)
    padded_so_segments = [np.pad(seg, (0, max_len_so - len(seg)), constant_values=np.nan) for seg in all_aligned_so_segments]
    avg_so_waveform = np.nanmean(padded_so_segments, axis=0)
    time_axis = np.linspace(-1.5, 1.5, len(avg_so_waveform))

    # pad spindles for STFT
    max_len_spindle = max(len(seg) for seg in all_aligned_spindle_segments)
    padded_spindle_segments = [np.pad(seg, (0, max_len_spindle - len(seg)), constant_values=np.nan) for seg in all_aligned_spindle_segments]

    Sxx_list = []
    baseline = np.mean([np.nanmean(s) for s in padded_spindle_segments if not np.isnan(s).all()])
    for seg in padded_spindle_segments:
        if np.isnan(seg).any():
            seg = np.nan_to_num(seg)
        seg = seg - baseline
        freqs, times, Sxx = signal.stft(seg, fs=sfreq, nperseg=int(sfreq/4), noverlap=int(sfreq/8))
        m = np.mean(Sxx)
        s = np.std(Sxx)
        Sxx = (Sxx - m) / s
        Sxx_list.append(np.abs(Sxx))
        # normalization

    avg_Sxx = np.nanmean(Sxx_list, axis=0)

    #cubic interpolation
    tim_interp = np.linspace(times.min(), times.max(), 5120)
    freq_interp = np.linspace(freqs.min(), freqs.max(), 1024)
    grid = (freqs, times)
    points = np.array(np.meshgrid(freq_interp, tim_interp, indexing='ij')).reshape(2, -1).T
    pow_interp_tf = interpn(grid, avg_Sxx, points, method='cubic')
    pow_interp_tf = pow_interp_tf.reshape(len(freq_interp), len(tim_interp))

    # plotting
    # setting the same axis legends
    fig, ax = plt.subplots(figsize=(10, 6), constrained_layout=True)
    im = ax.imshow(pow_interp_tf, aspect='auto', extent=[times.min()-1.5, times.max()-1.5, freqs.min(), freqs.max()], origin='lower', cmap='viridis', vmin=0, vmax=4)
    fig.colorbar(im, ax=ax, label='Power/Frequency (dB/Hz)', pad=0.01)

    ax2 = ax.twinx()
    ax2.plot(time_axis, avg_so_waveform, color='red', linewidth=2, label='Average SO')
    ax2.set_ylabel('Amplitude (µV)', color='red')
    ax2.tick_params(axis='y', labelcolor='red')
    ax2.set_ylim(-140, 40)
    ax2.axvline(0, color='white', linestyle='--', label="Trough (0s)")

    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Frequency (Hz)')
    ax.set_ylim(0, 30)
    ax.set_title("Average Coupled SO and Spindle STFT for 53 Participants")

    plt.show()
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# ...
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)

# %%
all_aligned_so_segments = []
all_aligned_spindle_segments = []

for pid in participant_ids:
    raw = combined_raw_data[pid]
    so_spindle_coupling_times = detect_slow_oscillations_spindles_coupling_so_times(raw, do_downsample=True)

    so_filtered_data = raw.copy().filter(l_freq=0.16, h_freq=1.25, verbose=False)
    so_filtered_data.resample(100)
    so_channel_data = so_filtered_data.get_data(picks="Fz")[0]
    sfreq = so_filtered_data.info['sfreq']

    spindle_filtered_data = raw.copy().filter(l_freq=12, h_freq=16, verbose=False)
    spindle_filtered_data.resample(100)
    spindle_channel_data = spindle_filtered_data.get_data(picks="Fz")[0]

    for start_time, end_time in so_spindle_coupling_times:
        start_idx = int(start_time * sfreq)
        end_idx = int(end_time * sfreq)
        so_segment = so_channel_data[start_idx:end_idx]
        if len(so_segment) == 0: continue
        trough_idx = np.argmin(so_segment) + start_idx
        
        before_trough_idx = max(0, trough_idx - int(1.5 * sfreq))
        after_trough_idx = min(len(so_channel_data), trough_idx + int(1.5 * sfreq))
        
        aligned_so_segment = so_channel_data[before_trough_idx:after_trough_idx]
        all_aligned_so_segments.append(aligned_so_segment)

        aligned_spindle_segment = spindle_channel_data[before_trough_idx:after_trough_idx]
        all_aligned_spindle_segments.append(aligned_spindle_segment)
    
    del raw, so_spindle_coupling_times, so_filtered_data, spindle_filtered_data

# --- Plotting section with constrained_layout ---
if all_aligned_so_segments:
    max_len_so = max(len(seg) for seg in all_aligned_so_segments)
    padded_so_segments = [np.pad(seg, (0, max_len_so - len(seg)), constant_values=np.nan) for seg in all_aligned_so_segments]
    avg_so_waveform = np.nanmean(padded_so_segments, axis=0)
    time_axis = np.linspace(-1.5, 1.5, len(avg_so_waveform))

    max_len_spindle = max(len(seg) for seg in all_aligned_spindle_segments)
    padded_spindle_segments = [np.pad(seg, (0, max_len_spindle - len(seg)), constant_values=np.nan) for seg in all_aligned_spindle_segments]

    Sxx_list = []
    baseline = np.mean([np.nanmean(s) for s in padded_spindle_segments if not np.isnan(s).all()])
    for seg in padded_spindle_segments:
        if np.isnan(seg).any(): seg = np.nan_to_num(seg)
        seg = seg - baseline
        freqs, times, Sxx = signal.stft(seg, fs=sfreq, nperseg=int(sfreq/4), noverlap=int(sfreq/8))
        m, s = np.mean(Sxx), np.std(Sxx)
        if s > 0: Sxx = (Sxx - m) / s
        Sxx_list.append(np.abs(Sxx))

    avg_Sxx = np.nanmean(Sxx_list, axis=0)

    tim_interp = np.linspace(times.min(), times.max(), 5120)
    freq_interp = np.linspace(freqs.min(), freqs.max(), 1024)
    grid = (freqs, times)
    points = np.array(np.meshgrid(freq_interp, tim_interp, indexing='ij')).reshape(2, -1).T
    pow_interp_tf = interpn(grid, avg_Sxx, points, method='cubic').reshape(len(freq_interp), len(tim_interp))

    # Using constrained_layout=True to manage spacing
    fig, ax = plt.subplots(figsize=(10, 6), constrained_layout=True)
    
    im = ax.imshow(pow_interp_tf, aspect='auto', extent=[times.min()-1.5, times.max()-1.5, freqs.min(), freqs.max()], origin='lower', cmap='viridis', vmin=0, vmax=4)
    fig.colorbar(im, ax=ax, label='Power/Frequency (dB/Hz)') # Removed pad argument

    ax2 = ax.twinx()
    ax2.plot(time_axis, avg_so_waveform, color='red', linewidth=2, label='Average SO')
    ax2.set_ylabel('Amplitude (µV)', color='red')
    ax2.tick_params(axis='y', labelcolor='red')
    ax2.set_ylim(-140, 40)
    ax2.axvline(0, color='white', linestyle='--', label="Trough (0s)")

    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Frequency (Hz)')
    ax.set_ylim(0, 30)
    ax.set_title("Average Coupled SO and Spindle STFT for 53 Participants")
    ax.legend()
    plt.show()
else:
    print("No SO-spindle coupling detected for any participant.")
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 38 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 38 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 38 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 15 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 15 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 15 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# ...
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 48 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 48 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 48 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
# C:\Users\roseb\AppData\Local\Temp\ipykernel_20772\3461318938.py:82: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
# For visualize_so_no_spindle_coupling
all_aligned_non_coupled_so_segments = []
all_aligned_non_coupled_spindle_segments = []

for pid in participant_ids:
    raw = combined_raw_data[pid]
    
    # Detect necessary events
    slow_oscillations_times = detect_slow_oscillations_times(raw, do_downsample=True)
    spindles_peaks = detect_spindles_peaks(raw, do_downsample=True)

    # Identify non-coupled SOs for the current participant
    non_coupled_so_times = []
    for start_time, end_time in slow_oscillations_times:
        coupled = False
        for peak in spindles_peaks:
            if start_time < peak < end_time:
                coupled = True
                break
        if not coupled:
            non_coupled_so_times.append((start_time, end_time))

    # Prepare filtered data
    so_filtered_data = raw.copy().filter(l_freq=0.16, h_freq=1.25)
    so_filtered_data.resample(100)
    so_channel_data = so_filtered_data.get_data(picks="Fz")[0]
    sfreq = so_filtered_data.info['sfreq']

    spindle_filtered_data = raw.copy().filter(l_freq=12, h_freq=16)
    spindle_filtered_data.resample(100)
    spindle_channel_data = spindle_filtered_data.get_data(picks="Fz")[0]

    # Align and collect segments for non-coupled SOs
    for start_time, end_time in non_coupled_so_times:
        start_idx = int(start_time * sfreq)
        end_idx = int(end_time * sfreq)
        
        so_segment = so_channel_data[start_idx:end_idx]
        if len(so_segment) == 0: continue # Skip if segment is empty
        trough_idx = np.argmin(so_segment) + start_idx
        
        before_trough_idx = max(0, trough_idx - int(1.5 * sfreq))
        after_trough_idx = min(len(so_channel_data), trough_idx + int(1.5 * sfreq))
        
        aligned_so_segment = so_channel_data[before_trough_idx:after_trough_idx]
        all_aligned_non_coupled_so_segments.append(aligned_so_segment)

        aligned_spindle_segment = spindle_channel_data[before_trough_idx:after_trough_idx]
        all_aligned_non_coupled_spindle_segments.append(aligned_spindle_segment)
    
    # Clear memory
    del raw
    del slow_oscillations_times
    del spindles_peaks
    del so_filtered_data
    del spindle_filtered_data

# Now, generate the combined plot for non-coupled events
if all_aligned_non_coupled_so_segments:
    # Pad and average SOs
    max_len_so = max(len(seg) for seg in all_aligned_non_coupled_so_segments)
    padded_so_segments = [np.pad(seg, (0, max_len_so - len(seg)), constant_values=np.nan) for seg in all_aligned_non_coupled_so_segments]
    avg_so_waveform = np.nanmean(padded_so_segments, axis=0)
    time_axis = np.linspace(-1.5, 1.5, len(avg_so_waveform))

    # Pad and process spindles for STFT
    max_len_spindle = max(len(seg) for seg in all_aligned_non_coupled_spindle_segments)
    padded_spindle_segments = [np.pad(seg, (0, max_len_spindle - len(seg)), constant_values=np.nan) for seg in all_aligned_non_coupled_spindle_segments]

    Sxx_list = []
    baseline = np.mean([np.nanmean(s) for s in padded_spindle_segments if not np.isnan(s).all()])
    for seg in padded_spindle_segments:
        if np.isnan(seg).any():
            seg = np.nan_to_num(seg)
        seg = seg - baseline
        freqs, times, Sxx = signal.stft(seg, fs=sfreq, nperseg=int(sfreq/4), noverlap=int(sfreq/8))
        m = np.mean(Sxx)
        s = np.std(Sxx)
        Sxx = (Sxx - m) / s
        Sxx_list.append(np.abs(Sxx))

    avg_Sxx = np.nanmean(Sxx_list, axis=0)
    
    # Interpolation
    tim_interp = np.linspace(times.min(), times.max(), 5120)
    freq_interp = np.linspace(freqs.min(), freqs.max(), 1024)
    grid = (freqs, times)
    points = np.array(np.meshgrid(freq_interp, tim_interp, indexing='ij')).reshape(2, -1).T
    pow_interp_tf = interpn(grid, avg_Sxx, points, method='cubic')
    pow_interp_tf = pow_interp_tf.reshape(len(freq_interp), len(tim_interp))

    # Plotting
    fig, ax = plt.subplots(figsize=(10, 6))
    im = ax.imshow(pow_interp_tf, aspect='auto', extent=[times.min()-1.5, times.max()-1.5, freqs.min(), freqs.max()], origin='lower', cmap='viridis', vmin=0, vmax=4)
    fig.colorbar(im, ax=ax, label='Power/Frequency (dB/Hz)', pad=0.02)

    ax2 = ax.twinx()
    ax2.plot(time_axis, avg_so_waveform, color='red', linewidth=2, label='Average SO')
    ax2.set_ylabel('Amplitude (µV)', color='red')
    ax2.tick_params(axis='y', labelcolor='red')
    ax2.set_ylim(-140, 40)
    ax2.axvline(0, color='white', linestyle='--', label="Trough (0s)")

    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Frequency (Hz)')
    ax.set_ylim(0, 30)
    ax.set_title("Average Non-Coupled SO and Spindle STFT for 53 Participants")
    ax.legend()
    plt.show()
else:
    print("No non-coupled SOs detected for any participant.")
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 26 contiguous segments
# ...
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 48 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 48 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
# C:\Users\roseb\AppData\Local\Temp\ipykernel_20772\1784443062.py:107: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
# For visualize_so_no_spindle_coupling (using constrained_layout)
all_aligned_non_coupled_so_segments = []
all_aligned_non_coupled_spindle_segments = []

# --- Data aggregation loop (same as before) ---
for pid in participant_ids:
    raw = combined_raw_data[pid]
    
    slow_oscillations_times = detect_slow_oscillations_times(raw, do_downsample=True)
    spindles_peaks = detect_spindles_peaks(raw, do_downsample=True)

    non_coupled_so_times = []
    for start_time, end_time in slow_oscillations_times:
        coupled = any(start_time < peak < end_time for peak in spindles_peaks)
        if not coupled:
            non_coupled_so_times.append((start_time, end_time))

    so_filtered_data = raw.copy().filter(l_freq=0.16, h_freq=1.25, verbose=False)
    so_filtered_data.resample(100)
    so_channel_data = so_filtered_data.get_data(picks="Fz")[0]
    sfreq = so_filtered_data.info['sfreq']

    spindle_filtered_data = raw.copy().filter(l_freq=12, h_freq=16, verbose=False)
    spindle_filtered_data.resample(100)
    spindle_channel_data = spindle_filtered_data.get_data(picks="Fz")[0]

    for start_time, end_time in non_coupled_so_times:
        start_idx, end_idx = int(start_time * sfreq), int(end_time * sfreq)
        so_segment = so_channel_data[start_idx:end_idx]
        if len(so_segment) == 0: continue
        trough_idx = np.argmin(so_segment) + start_idx
        
        before_trough_idx = max(0, trough_idx - int(1.5 * sfreq))
        after_trough_idx = min(len(so_channel_data), trough_idx + int(1.5 * sfreq))
        
        aligned_so_segment = so_channel_data[before_trough_idx:after_trough_idx]
        all_aligned_non_coupled_so_segments.append(aligned_so_segment)

        aligned_spindle_segment = spindle_channel_data[before_trough_idx:after_trough_idx]
        all_aligned_non_coupled_spindle_segments.append(aligned_spindle_segment)
    
    del raw, slow_oscillations_times, spindles_peaks, so_filtered_data, spindle_filtered_data

# --- Plotting section with constrained_layout ---
if all_aligned_non_coupled_so_segments:
    max_len_so = max(len(seg) for seg in all_aligned_non_coupled_so_segments)
    padded_so_segments = [np.pad(seg, (0, max_len_so - len(seg)), constant_values=np.nan) for seg in all_aligned_non_coupled_so_segments]
    avg_so_waveform = np.nanmean(padded_so_segments, axis=0)
    time_axis = np.linspace(-1.5, 1.5, len(avg_so_waveform))

    max_len_spindle = max(len(seg) for seg in all_aligned_non_coupled_spindle_segments)
    padded_spindle_segments = [np.pad(seg, (0, max_len_spindle - len(seg)), constant_values=np.nan) for seg in all_aligned_non_coupled_spindle_segments]

    Sxx_list = []
    baseline = np.mean([np.nanmean(s) for s in padded_spindle_segments if not np.isnan(s).all()])
    for seg in padded_spindle_segments:
        if np.isnan(seg).any(): seg = np.nan_to_num(seg)
        seg = seg - baseline
        freqs, times, Sxx = signal.stft(seg, fs=sfreq, nperseg=int(sfreq/4), noverlap=int(sfreq/8))
        m, s = np.mean(Sxx), np.std(Sxx)
        if s > 0: Sxx = (Sxx - m) / s
        Sxx_list.append(np.abs(Sxx))

    avg_Sxx = np.nanmean(Sxx_list, axis=0)

    tim_interp = np.linspace(times.min(), times.max(), 5120)
    freq_interp = np.linspace(freqs.min(), freqs.max(), 1024)
    grid = (freqs, times)
    points = np.array(np.meshgrid(freq_interp, tim_interp, indexing='ij')).reshape(2, -1).T
    pow_interp_tf = interpn(grid, avg_Sxx, points, method='cubic').reshape(len(freq_interp), len(tim_interp))

    # Using constrained_layout=True to manage spacing
    fig, ax = plt.subplots(figsize=(10, 6), constrained_layout=True)
    
    im = ax.imshow(pow_interp_tf, aspect='auto', extent=[times.min()-1.5, times.max()-1.5, freqs.min(), freqs.max()], origin='lower', cmap='viridis', vmin=0, vmax=4)
    fig.colorbar(im, ax=ax, label='Power/Frequency (dB/Hz)') # Removed pad argument

    ax2 = ax.twinx()
    ax2.plot(time_axis, avg_so_waveform, color='red', linewidth=2, label='Average SO')
    ax2.set_ylabel('Amplitude (µV)', color='red')
    ax2.tick_params(axis='y', labelcolor='red')
    ax2.set_ylim(-140,40)
    ax2.axvline(0, color='white', linestyle='--', label="Trough (0s)")

    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Frequency (Hz)')
    ax.set_ylim(0, 30)
    ax.set_title("Average Non-Coupled SO and Spindle STFT for 53 Participants")
    ax.legend()
    plt.show()
else:
    print("No non-coupled SOs detected for any participant.")
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 19 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 35 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 13 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 14 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 31 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 38 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 38 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 15 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 15 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 26 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 20 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 29 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 29 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 16 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ...
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 41 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 41 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 30 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 30 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 29 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 29 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 24 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 33 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 48 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 48 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 40 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 22 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 27 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 0.16 - 1.2 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.16
# - Lower transition bandwidth: 0.16 Hz (-6 dB cutoff frequency: 0.08 Hz)
# - Upper passband edge: 1.25 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.25 Hz)
# - Filter length: 10313 samples (20.626 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 25 contiguous segments
# Setting up band-pass filter from 12 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 12.00
# - Lower transition bandwidth: 3.00 Hz (-6 dB cutoff frequency: 10.50 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 4.00 Hz (-6 dB cutoff frequency: 18.00 Hz)
# - Filter length: 551 samples (1.102 s)
# C:\Users\roseb\AppData\Local\Temp\ipykernel_20772\784710487.py:89: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
